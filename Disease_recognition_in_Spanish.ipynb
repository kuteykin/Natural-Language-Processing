# %% [markdown]
# # Token Classification: customisation of NER tagging model for recognition of new entity using *spaCy*

# %% [markdown]
# ## OBJECTIVE: recognise and tag all diseases from medical records / scientific literature in Spanish language

# %% [markdown]
# ### Task 1: Make model to recognise all named entities in Spanish including diseases
#
# ###  Task 2: read the text from all tweets in "*/training*" directory, tokenize it and label the tokens with IOB ner_tags *(for Spanish disease names only, ignoring other entities)*

# %% [markdown]
# ### Datasets:
# 1. *'Listado_enfermedades_CIE-10.csv'* : Disease list from CIE-10 (IDC-10, International Classification of Diseases 10th Revision, Spanish version https://icdcode.info/espanol/cie-10/codigos.html). This CSV list forked from https://github.com/verasativa/CIE-10 .
# 2. *'enfermedades_tweets.txt'* : List of "common names" of diseases in Spanish obtained by scraping from tweets *(private, not uploaded to GitHub)*
# 3. *'/training/ * .txt'*: Collection of 5.000 Spanish tweets mentioning diseases and pathologies, one tweet per * .txt file *(private, not uploaded to GitHub)*

# %%
# Importing basic libraries
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Installation of spaCy models for Spanish (https://spacy.io/models/es)

# !python -m spacy download es_core_news_sm    # Small model

# !python -m spacy download es_core_news_md    # Medium-size model

# !python -m spacy download es_core_news_lg    # Long model

# !python -m spacy download es_dep_news_trf    # Transformer pipeline (dccuchile/bert-base-spanish-wwm-cased)

# %%
import re

# %%
from pathlib import Path

# %%
training_dir = Path('Input/training')

# %% [markdown]
# ### Load input examples and disease database

# %% [markdown]
# **Challenges**:
# 1. Uppercase/Lowercase
# 2. Unicode characters (e.g.: 'á', 'é', 'í', 'ü', 'â', 'ñ' might be written different way)
# 3. Multiple entries of the same disease (*'covid'/'covid-19'/'covid 19'*;  *'diabetis'/'diabet'/'diabética'*)
#
# **Normalization** and **Curation** might be necessary for some approaches:
# 1. Normalization for disease list and for every input text (tweet) before analysis.
# 2. For DL approach: train model for all possible spelling variants

# %%
# Input standartization (Uppercase/lowercase, unicode chars)

import unicodedata
def normalize_caseless(text):
    return unicodedata.normalize("NFKD", text.casefold())

# %%
# Reading of list from file (one disease name per line)
#'Common names" for diseases obtained from tweets

with open('Input/enfermedades_tweets.txt') as file:
    diseases_from_tweets= re.split(r'[\n#@%:;¡!?¿/]', normalize_caseless(file.read()))

# %%
diseases_from_tweets
# Out:
# ['abcesos intrabdominales',
#  'abdomen agudo',
#  'aborto',
#  'aborto espontáneo',
#  'abortoperinatal',
#  'abortos',
#  'abortos de primer y segundo trimestre',
#  'absceso',
#  'absceso dental',
#  'abscesos',
#  'abscesos abdominales',
#  'abscesos dentales por culpa de una caries',
#  'abuso',
#  'abuso a mujeres y niñas con parálisis cerebral',
#  'abuso de alcohol',
#  'abuso de alcohol y tabaco',
#  'abuso de benzos',
#  'abuso de drogas',
#  'abuso de las pantallas',
#  'abuso de sustancias',
#  'abuso del alcohol',
#  'abuso sexual infantil',
#  'acantosis nigricans',
#  'acantosis nigrocans',
#  'accidente cerebro',
#  'accidente cerebro vascular',
#  'accidente cerebro vascular no especificado',
#  'accidente cerebrovascular',
#  'accidente cerebrovascular isquémico',
#  'accidentes cerebrovasculares',
#  'accidentes laborales',
#  'accidentes vasculares',
#  'accreta',
#  'acidosis',
#  'acidosis hipercl',
#  'acidosis hiperclorémica',
#  'acidosis metabólica',
#  'acné',
#  'acné grave',
#  'acondroplasia',
#  'acretismo placentario',
#  'acumulación atípica de grasa en las extremidades',
#  'acv criptogénico',
#  'acv en ganglios basales',
#  'acv isquémicos',
#  'acv lacunar',
#  'adenitis',
#  'adenocarcinoma',
#  'adenocarcinoma de pulmón',
#  'adenomiosis',
#  'adenopatías',
#  'adenopatías biliares bilaterales',
#  'adiccion',
#  'adicciones',
#  'adicciones ',
#  'adicción',
#  'adicción a la cocaína y la heroína',
#  'adicción a las redes sociales',
#  'adicción a lo digital',
#  'adicción al tabaco',
#  'adicción como alcohol',
#  'adictos a alguna sustancia',
#  'adolescencia y ',
#  'advp',
#  'afasia',
#  'afasiaprogresivaprimaria',
#  'afasias',
#  'afasias progresivas',
#  'afecciones del corazón',
#  'afecciones neurológicas',
#  'afecciones oculares',
#  'afecciones respiratorias',
#  'afección broncopulmonar',
#  'afección cardíaca',
#  'afectación articular',
#  'afectación de la retina',
#  'afectación en el sistema de conducción cardiaco',
#  'aftas',
#  'aftas bucales',
#  'aftasbucales',
#  'agenesia del sexto par',
#  'agorafobia',
#  'agrandamiento de los ventrículos cerebrales',
#  'aids',
#  'aines',
#  'alcalosis',
#  'alcoholismo',
#  'alcohólica',
#  'alcohólico',
#  'alcohólicos',
#  'aldrich',
#  'alergia',
#  'alergia  ',
#  'alergia a algún medicamento',
#  'alergia a alimentos',
#  'alergia a frutos secos',
#  'alergia a los acaros',
#  'alergia a medicamentos',
#  'alergia al ',
#  'alergia al limón',
#  'alergia al polvo',
#  'alergia al sol',
#  'alergia alimentaria',
#  'alergia cutánea',
#  'alergia de un cosmético',
#  'alergia respiratoria',
#  'alergia solar',
#  'alergiafrutossecos',
#  'alergiaocupacional',
#  'alergias',
#  'alergias alimentarias',
#  'alergias psicológicas',
#  'alergias respiratorias',
#  'alerxia ao trigo',
#  'alexithymia',
#  'alérgica',
#  'alérgica a la penicilina',
#  'alérgica a todo tipo de plantas',
#  'alérgica a varios medicamentos como antibióticos, analgésicos',
#  'alérgico',
#  'alérgico a los perros',
#  'alérgico a un componente de la vacuna',
#  'alérgicos',
#  'alérgicos a ácaros',
#  'algias faciales',
#  'allergy',
#  'alopecia',
#  'alopecia androgenética',
#  'alopecia apolillada',
#  'alopecia areata',
#  'alopecia difusa',
#  'alopecia parcheada',
#  'alt hematológicas',
#  'alteraciones  en la  piel',
#  'alteraciones cognitivas',
#  'alteraciones conductuales graves',
#  'alteraciones del ciclo menstrual',
#  'alteraciones del sueño',
#  'alteraciones dermatológicas',
#  'alteraciones en el funcionamiento de órganos',
#  'alteraciones metabólicas',
#  'alteración de su sistema circulatorio',
#  'alteración del metabolismo y la densidad ósea',
#  'alteración neurpsi',
#  'alucinaciones visuales complejas de personas y animales.',
#  'alveolitis',
#  'alzeimer',
#  'alzheimer',
#  'alzheimer ',
#  'alzheimer infantil',
#  'alzheimers',
#  'alzhéimer',
#  'ambliopía',
#  'ame tipo 2',
#  'amenaza de aborto',
#  'amigdalitis',
#  'amigdalitis calcificadas',
#  'amiloidosis',
#  'amiloidosis cutánea primaria',
#  'amiloidosis hereditaria por transtirretina',
#  'amiloidosis macular',
#  'amiloidosis sistémica',
#  'amiloidosis ttr hereditaria',
#  'amnesias',
#  'ampolla en el pie',
#  'ampolla subepidérmica',
#  'amputaciones',
#  'amputación traumatica de dedo',
#  'amyloidosis',
#  'anafilaxia',
#  'anafilaxia con griseofulvina',
#  'anasalaschacon',
#  'anemia',
#  'anemia aguda',
#  'anemia aplasica',
#  'anemia aplásica',
#  'anemia aplásica severa',
#  'anemia ferropénica',
#  'anemia infantil',
#  'anemia leve',
#  'anemia megaloblástica',
#  'anemia moderada',
#  'anemia normo normo',
#  'anemia por ',
#  'anemia por sangrado',
#  'anemica',
#  'anemización',
#  'anetodermia primaria',
#  'aneurisma',
#  'aneurisma micotico',
#  'aneurismas',
#  'aneurismas abdominales',
#  'aneurismas cerebrales',
#  'anémica',
#  'angina',
#  'angina de pecho',
#  'angina inestable',
#  'anginas',
#  'angioedema retardado por presión',
#  'angiofibromas',
#  'angor',
#  'anguria',
#  'angustia',
#  'angustia profunda',
#  'angustiado',
#  'anisocoría',
#  'anisometropía',
#  'ankilosingspondylitis',
#  'ankylosingspondylitis',
#  'anomalías viscerales',
#  'anorexia',
#  'anorexia nerviosa',
#  'anorexia nerviosa restrictiva',
#  'anorexianerviosa',
#  'anoréxica',
#  'anorgasmia',
#  'anosmia residual absoluta',
#  'anoxias',
#  'ansiedad',
#  'ansiedad a las hipoglucemias',
#  'ansiedad en adultos con tea',
#  'ansiedad en el autismo',
#  'ansiedad generalizada',
#  'ansiedad obsesiva',
#  'ansiedad por hiper o hipoglucemia',
#  'ansiedad relacionada al morir',
#  'ansiedad social',
#  'ansiosa',
#  'ansiosas',
#  'ansioso',
#  'ansiosos',
#  'antes de quitarte',
#  'antisocial',
#  'anxiety',
#  'anxietydisorders',
#  'año a los nervios,',
#  'año ocular,',
#  'año renal,',
#  'aortitis por sífilis',
#  'apendicitis',
#  'aplasia del núcleo',
#  'aplasia medular',
#  'aplasia medular severa ideopatica',
#  'aplastamiento de músculo esquelético',
#  'apnea del sueño',
#  'apnea obstructiva del sueño',
#  'ar activa',
#  'ar refractaria',
#  'arañas vasculares',
#  'areata',
#  'arnold chiari',
#  'arnoldchiari',
#  'arritmia',
#  'arritmia cardíaca',
#  'arritmia cardíaca leve',
#  'arritmias',
#  'arritmias cardiacas',
#  'arteriosclerosis',
#  'arteriosclerosis coronaria',
#  'arteritis',
#  'arteritis de takayasu',
#  'arthritis',
#  'articulaciones de mi mano ya están muy laxas producto de la artritis',
#  'artritis',
#  'artritis degenerativa',
#  'artritis en codo',
#  'artritis idiopática juvenil',
#  'artritis inflamatorias',
#  'artritis microcristalinas',
#  'artritis muy grave',
#  'artritis psoriasica',
#  'artritis psoriatica',
#  'artritis psoriásica',
#  'artritis reactiva',
#  'artritis reumatoide',
#  'artritis reumatoide juvenil',
#  'artritisjuvenil',
#  'artritispsoriasica',
#  'artritispsoriásica',
#  'artritisreumatoide',
#  'artrogriposis',
#  'artrosis',
#  'artrosis de cadera',
#  'artrosis de manos',
#  'artrosis de rodilla',
#  'artrosis de rodillas',
#  'artrosis degenerativa',
#  'artrosis en cadera',
#  'artrosis en diferentes articulaciones',
#  'artrosis lumbar',
#  'artrotisreumatoide',
#  'ascitis',
#  'asfixia',
#  'asfixia por atragantamiento',
#  'asma bronquial',
#  'asma crónica',
#  'asma grave',
#  'asma intermitente',
#  'asma moderada o grave',
#  'asmainfantil',
#  'asmas',
#  'asmática',
#  'asmática crónica',
#  'asmático',
#  'asmáticos',
#  'asperger',
#  'aspergiano',
#  'aspergilloma pulmonar',
#  'aspergilosis',
#  'astenia otoñal',
#  'asthma',
#  'astigmatismo',
#  'astma',
#  'asunto respiratorio',
#  'ataque',
#  'ataque al corazón',
#  'ataque al sistema inmunológico',
#  'ataque cardíaco',
#  'ataque de ansiedad',
#  'ataque de asma',
#  'ataque de epilepsia',
#  'ataque de panico',
#  'ataque de pánico',
#  'ataque de rabia con ansiedad',
#  'ataque epiléptico',
#  'ataque isquémico transitorio',
#  'ataquedeansiedad',
#  'ataques',
#  'ataques al corazón',
#  'ataques de ansiedad',
#  'ataques de ansiedad e impulsividad',
#  'ataques de asma',
#  'ataques de epilepsia',
#  'ataques de pánico',
#  'ataques de pánico, de ansiedad',
#  'ataques de pánicos',
#  'ataques epiléptico',
#  'ataquesdenasiedad',
#  'ataquesdepanico',
#  'ataxia',
#  'ateroesclerosis',
#  'aterosclerosis',
#  'atiquifobia',
#  'atopia',
#  'atópica',
#  'atópicos',
#  'atracón',
#  'atragantamiento',
#  'atrapamiento nervio isquio',
#  'atresia esofágica',
#  'atrofia cerebral',
#  'atrofia cerebral de la enfermedad de alzheimer',
#  'atrofia geográfica',
#  'atrofia muscular',
#  'atrofia muscular espinal',
#  'atrofia óptica',
#  'atrofia severa de deltoides',
#  'atrofia vulvar',
#  'atrofiageográfica',
#  'atrofiar el chumino',
#  'atrofias',
#  'attrh',
#  'aumento consumo alcohol',
#  'aumento de colesterol',
#  'ausencia',
#  'ausencia típica de la infancia',
#  'autimo',
#  'autis',
#  'autisimo',
#  'autism',
#  'autismo',
#  'autismo moderado',
#  'autismoinfantil',
#  'autista',
#  'autistas',
#  'autistas sin discapacidad intelectual',
#  'autistic',
#  'autofobia',
#  'autoimmune sistémica',
#  'autoimmunity',
#  'autoinmues',
#  'autoinmune',
#  'autoinmunes',
#  'autolesionandome',
#  'autolesiones',
#  'ácido úrico alto',
#  'ásperger',
#  'bacterias resistentes',
#  'bacteriemias',
#  'baja sensibilidad en receptores de andrógenos',
#  'baja visión',
#  'bajavisión',
#  'bajo peso al nacer',
#  'barré',
#  'basocelular',
#  'bazo lleno de tumores',
#  'bcrihh',
#  'beber alcohol',
#  'bebés prematuros con hemorragia intraventricular (ivh) severa',
#  'behçet',
#  'benigna',
#  'bigorexia',
#  'bipolar',
#  'bipolares',
#  'bipolaridad',
#  'bipolaridad tipo 2',
#  'bipolaridades',
#  'bizca',
#  'blefaritis',
#  'blefaritis anterior',
#  'blefaritis posterior',
#  'bloqueo 💔grado 1 o 2',
#  'bloqueos mentales',
#  'bocio',
#  'bocio multinodular',
#  'bogifobia',
#  'bootcamps',
#  'borderline personality disorder',
#  'borderlinepersonalitydisorder',
#  'boronquitis',
#  'bradicardia',
#  'breast cancer',
#  'breastcancer',
#  'broca',
#  'broncoespasmo',
#  'broncoestasis',
#  'bronconeumonia',
#  'bronqueictasias',
#  'bronquiectasia centrales',
#  'bronquiectasias',
#  'bronquiectasis',
#  'bronquiolitis',
#  'bronquiolitis grave',
#  'bronquiolitis por vrs',
#  'bronquiolitis vrs+',
#  'bronquitis',
#  'bronquitis cronica',
#  'bronquitis crónica',
#  'bronquitis en la infancia',
#  'brosis pulmonar, ',
#  'brote ',
#  'brote psicótico',
#  'brotebpd',
#  'brotes agudos migrañoso',
#  'brotes psicóticos',
#  'bruxismo',
#  'buenosdias',
#  'bulimia',
#  'bulto en el pecho',
#  'bultos en el pecho',
#  'burnout',
#  'burnout autista',
#  'bursitis',
#  'c. vegiga',
#  'ca de colon',
#  'ca de páncreas',
#  'ca de páncreas y riñón',
#  'ca de próstata',
#  'ca páncreas',
#  'ca renal',
#  'ca. adenoide quístico de glándula lagrimal',
#  'calcificaciones',
#  'calcificaciones psammomatosas en un adenocarcinoma de pulmón',
#  'callo',
#  'cambios mentales',
#  'canalopatía atípica',
#  'cancer',
#  'cancer de colon',
#  'cancer de hígado',
#  'cancer de mama',
#  'cancer de mamá con metástasis en los ganglios',
#  'cancer de prostata',
#  'cancer de pulmon',
#  'cancer de pulmón',
#  'cancer de riñón',
#  'cancer en el hígado',
#  'cancer infantil',
#  'cancer renal',
#  'cancerdecolon',
#  'cancerdemama',
#  'cancerdemamametastasico',
#  'cancerdemamas',
#  'cancerdeovario',
#  'cancerdeprostata',
#  'cancerdepulmon',
#  'cancerdepulmón',
#  'canceres',
#  'cancerinfantil',
#  'cancerlaboral',
#  'cancermama',
#  'cancerpulmon',
#  'cancerpulmonar',
#  'cancro',
#  'cancro infantil',
#  'candidiasis',
#  'cansancio post covid',
#  'caquexia',
#  'cara destrozada',
#  'carcinoma',
#  'carcinoma anaplásico',
#  'carcinoma de células escamosas',
#  'carcinoma de células grandes',
#  'carcinoma ductal',
#  'carcinoma en el pecho',
#  'carcinoma folicular',
#  'carcinoma gástrico',
#  'carcinoma medular',
#  'carcinoma medular de tiroides',
#  'carcinoma microcitico de pulmón',
#  'carcinoma papilar',
#  'carcinoma suprarrenal',
#  'carcinoma tímico',
#  'carcinomas tímicos',
#  'carcinomatosis peritoneal',
#  'cardiacos',
#  'cardiomegalia',
#  'cardiomiopatía',
#  'cardiomiopatía alcohólica',
#  'cardiopatia',
#  'cardiopatia congénita',
#  'cardiopatía',
#  'cardiopatía congénita',
#  'cardiopatía de takotsubo',
#  'cardiopatía en el corazón',
#  'cardiopatía hipertensiva',
#  'cardiopatía isquémica',
#  'cardiopatías',
#  'cardiopatías coronarias',
#  'cardiopatías isquémicas',
#  'cardiopatías isquémicas 👇',
#  'cardiotoxicidad inducida por la quimioterapia',
#  'cardiovascular',
#  'cardiovascular events',
#  'cardiópata',
#  'cardiópatas',
#  'carencias alimenticias',
#  'caries',
#  'caries dental',
#  'caspa',
#  'catarartas',
#  'catarata',
#  'cataratas',
#  'cataratas ',
#  'cataratas a raíz de rayos uv',
#  'catarrales',
#  'catarrazo',
#  'catarro',
#  'catarro común',
#  'catarro de vías altas',
#  'catarros',
#  'catatonia',
#  'catatónicos',
#  'cavidad secuela de tuberculosis',
#  'cálculos',
#  'cáncer',
#  'cáncer adulto',
#  'cáncer agresivo',
#  'cáncer al pulmón',
#  'cáncer anal',
#  'cáncer avanzado',
#  'cáncer cerebral',
#  'cáncer cerebral infantil',
#  'cáncer cervicouterino',
#  'cáncer colorrectal',
#  'cáncer con metástasis',
#  'cáncer d colon',
#  'cáncer d colón, d páncreas, d mama',
#  'cáncer d mama',
#  'cáncer de cabeza y cuello',
#  'cáncer de cabeza y cuello, pulmón',
#  'cáncer de cervix',
#  'cáncer de cérvix',
#  'cáncer de colon',
#  'cáncer de colón',
#  'cáncer de cuello de útero',
#  'cáncer de cuello uterino',
#  'cáncer de endometrio',
#  'cáncer de estómago',
#  'cáncer de garganta',
#  'cáncer de hígado',
#  'cáncer de hígado y vías biliares',
#  'cáncer de la piel',
#  'cáncer de la sangre',
#  'cáncer de lengua y de vejiga',
#  'cáncer de los adultos',
#  'cáncer de mama',
#  'cáncer de mama ',
#  'cáncer de mama con metástasis',
#  'cáncer de mama er+',
#  'cáncer de mama grado 4 con metástasis lumbar',
#  'cáncer de mama luminal',
#  'cáncer de mama metastásico',
#  'cáncer de mama precoz hormono dependiente her2 ',
#  'cáncer de mama y colon',
#  'cáncer de mama y ovario',
#  'cáncer de mama y próstata',
#  'cáncer de mamas',
#  'cáncer de mamá',
#  'cáncer de médula mieloma múltiple',
#  'cáncer de ovario',
#  'cáncer de ovarios o de mama',
#  'cáncer de pancreas',
#  'cáncer de páncreas',
#  'cáncer de páncreas en remisión',
#  'cáncer de páncreas y riñón',
#  'cáncer de piel',
#  'cáncer de próstata',
#  'cáncer de próstata y testicular',
#  'cáncer de pulmón',
#  'cáncer de pulmón con metástasis en  el hígado',
#  'cáncer de pulmón con varias metástasis',
#  'cáncer de pulmón de células no pequeñas',
#  'cáncer de pulmón microcítico',
#  'cáncer de pulmón no microcítico',
#  'cáncer de pulmón y colon',
#  'cáncer de pulmón, esófago, mama',
#  'cáncer de riñón',
#  'cáncer de seno',
#  'cáncer de utero',
#  'cáncer de útero',
#  'cáncer de vejiga',
#  'cáncer digestivo',
#  'cáncer gastrointestinal',
#  'cáncer genitourinario, ginecológico',
#  'cáncer ginecológico',
#  'cáncer hematologico',
#  'cáncer hematológico',
#  'cáncer hereditario',
#  'cáncer infantil',
#  'cáncer laboral',
#  'cáncer metastásico',
#  'cáncer metastásico en cerebro',
#  'cáncer oral',
#  'cáncer provocado por el tabaco',
#  'cáncer rectal',
#  'cáncer renal',
#  'cáncer testicular',
#  'cáncer toracoabdominal',
#  'cáncer vestibular',
#  'cáncercabezaycuello',
#  'cáncerdehígado',
#  'cáncerdemama',
#  'cáncerdemediastino',
#  'cáncerdepiel',
#  'cáncerdepróstata',
#  'cáncerdepulmón',
#  'cáncerdepulmón de células no pequeñas',
#  'cáncerdetiroides',
#  'cánceres',
#  'cáncerinfantil',
#  'cáncerpulmón',
#  'cáncer👿 cervicouterino',
#  'cefalea migrsñosa crónica',
#  'cefalea tensional',
#  'cefalea, ',
#  'cefaleas',
#  'ceguera',
#  'celiaco',
#  'celiacos',
#  'celiaquia',
#  'celiaquismo',
#  'celiaquía',
#  'celíaca',
#  'celíaco',
#  'celulitis',
#  'cerebral',
#  'cervicalgia',
#  'cervicoartrosis',
#  'cetoacidosis',
#  'cetoacidosis grave',
#  'cetoacidosis graves',
#  'cetoacidosis severa',
#  'cetosis',
#  'células en anillo de sello y',
#  'chancro',
#  'charcot, la neuropatía',
#  'chester',
#  'chiari',
#  'choque',
#  'chron',
#  'chronic fatigue syndrome',
#  'ciática',
#  'cicatrices',
#  'cicatrices de episiotomia',
#  'cicatrices de las cirugías',
#  'cicatrices del corazón',
#  'cicatrices en el corazón',
#  'cicatrices en la piel',
#  'cicatrices en los pulmones',
#  'cicatriz',
#  'cicatriz de cesárea',
#  'ciega',
#  'ciegos',
#  'cifoescoliosis',
#  'cigarrillo',
#  'cigarrillos electrónicos',
#  'cirrosis',
#  'cirrosis hepatica',
#  'cirrosis hepática',
#  'cirrótica por vhc',
#  'cirróticos',
#  'cistitis',
#  'cistopatiainterscial',
#  'citomegalovirus',
#  'citopenias autoinmunes',
#  'civ muscular restrictiva',
#  'clamidia',
#  'clifahdd',
#  'coagulopatía',
#  'coagulopatía asociada a covid',
#  'coagulopatías',
#  'coagulopatías congénitas',
#  'coágulo de sangre en una vena',
#  'cocainofobia',
#  'cocainómanos',
#  'codo de golfista',
#  'cognitive dysfunction',
#  'coinfección',
#  'coinfección de covid',
#  'coinfección por vhd',
#  'coinfección vhb',
#  'cojera',
#  'colagenopatía',
#  'colangiocarcinoma',
#  'colangitis',
#  'colangitis biliar primaria',
#  'colangitis esclerosante primaria',
#  'colapso mental',
#  'colecistitis',
#  'colecistitis aguda',
#  'colestasis',
#  'colesterol',
#  'colesterol alto',
#  'colesterol malo en sangre',
#  'colitis',
#  'colitis isquémico',
#  'colitis nerviosa',
#  'colitis ulcerosa',
#  'colitisulcerativa',
#  'colitisulcerosa',
#  'colles',
#  'colon',
#  'colon irritable',
#  'columna',
#  'coma',
#  'coma diabético',
#  'coma etílico',
#  'coma hiperosmolar',
#  'coma inducido por covid',
#  'comedones',
#  'complicacion cardiaca grave',
#  'complicaciones cardiovasculares, cerebrales',
#  'complicaciones cardiovasulares por sars',
#  'complicaciones causadas por ambas enfermedades',
#  'complicaciones cutáneas de la ',
#  'complicaciones de los pies por diabetes',
#  'complicaciones endocrino',
#  'complicaciones macroangiopaticas',
#  'complicaciones neurológicas',
#  'complicaciones oculares',
#  'complicaciones relacionadas con el parto',
#  'complicación cardíaca y de los vasos sanguíneos',
#  'complicación grave por las secuelas',
#  'complicación psiquiátrica',
#  'compresión neoplasica',
#  'comunicación',
#  'comunicación pulpar',
#  'comunicativo',
#  'condiciones discapacitantes',
#  'condición autista',
#  'condición autoinmune',
#  'condilomas',
#  'condrocalcinosis',
#  'condromalacia',
#  'condromalacia en ambas rodillas',
#  'condromalacia rotuliana',
#  'condrosarcoma',
#  'conducta auto lesiva',
#  'conducta evitativa',
#  'conductas adictivas',
#  'conductas obsesivas',
#  'conductas suicidas',
#  'confecciones con vhc y vih',
#  'confusional',
#  'congestión vascular',
#  'conjuntivitis',
#  'conjuntivitis alérgica',
#  'conjuntivitis alérgicas',
#  'conjuntivitis bacteriana',
#  'conjuntivitis crónica',
#  'conjuntivitis en los ojos',
#  'conjuntivitis víricas y bacterianas',
#  'conjutivitis',
#  'conmoción cerebral',
#  'consejofarmacéutico',
#  'consumo abusivo de alcohol',
#  'consumo d drogas d forma crónica',
#  'consumo de ',
#  'consumo de alcohol',
#  'consumo de alcohol, drogas',
#  'consumo de cannabis',
#  'consumo de cocaina',
#  'consumo de cocaína',
#  'consumo de drogas',
#  'consumo de drogas e alcohol',
#  'consumo de drogas entre adolescentes',
#  'consumo de estupefacientes',
#  'consumo de marihuana',
#  'consumo de sustancias',
#  'consumo de sustancias excitantes',
#  'consumo de tabaco',
#  'consumo de tabaco y nicotina',
#  'consumo de tabaquisimo y alcohol',
#  'consumo excesivo de alcohol',
#  'consumo nocivo de alcohol',
#  'consumo prolongado de sustancias',
#  'contagiadas por ',
#  'contagio de covid',
#  'contagios por coronavirus',
#  'contagiosas',
#  'contractura',
#  'contractura capsular',
#  'contractura cervical',
#  'contractura de dupuytren',
#  'contractura de los trapecios',
#  'contractura del gemelo',
#  'contractura en el cuello',
#  'contractura en la espalda',
#  'contracturado',
#  'contracturas',
#  'convulsiones',
#  'convulsiones febriles',
#  'convulsión',
#  'convulsión febril',
#  'coqueluche',
#  'corazón crecido',
#  'coronario crónico',
#  'coronavid19',
#  'coronavirus',
#  'costocondritis',
#  'covid',
#  'covid con neumonía',
#  'covid con secuelas',
#  'covid con sintomas leves',
#  'covid embarazo y aborto',
#  'covid en su fase mas aguda',
#  'covid grave',
#  'covid leve',
#  'covid persistente',
#  'covid persistente grave',
#  'covid persistente no es sfc',
#  'covid prolongado',
#  'covid-19',
#  'covid-2019',
#  'covid19',
#  'covid2019',
#  'covid_19',
#  'covid_2019',
#  'covid__19',
#  'covidceguera',
#  'covidflu',
#  'covidー19',
#  'coxalgia',
#  'cólera',
#  'cólico',
#  'cólico menstrual',
#  'cólico nefrítico',
#  'cólicos',
#  'cpersistente',
#  'crisi',
#  'crisis',
#  'crisis alérgica',
#  'crisis alérgicas',
#  'crisis asmática',
#  'crisis asmáticas',
#  'crisis borderline',
#  'crisis climática',
#  'crisis convulsiva',
#  'crisis convulsivas',
#  'crisis coronavirus',
#  'crisis de angustia',
#  'crisis de ansiedad',
#  'crisis de apnea',
#  'crisis de asma',
#  'crisis de ausencia',
#  'crisis de depresión',
#  'crisis de dolor',
#  'crisis de epilepsia',
#  'crisis de inflamación',
#  'crisis de miastenia',
#  'crisis de migrañas con aura',
#  'crisis de nervios',
#  'crisis de pánico',
#  'crisis de repetición',
#  'crisis de trastorno personalidad narcisista',
#  'crisis del ',
#  'crisis del covid',
#  'crisis depresivas',
#  'crisis epiléptica',
#  'crisis epilépticas',
#  'crisis epilépticas no controladas',
#  'crisis existencial',
#  'crisis general y, por salud mental',
#  'crisis hipertensiva',
#  'crisis hipertensivas',
#  'crisis hípertension arterial',
#  'crisis miastenica',
#  'crisis mioclónicas',
#  'crisis nerviosas',
#  'crisis nocturnas',
#  'crisis provocada por el coronavirus',
#  'crisis renal esclerodérmica',
#  'crisis vertiginosa',
#  'crohn',
#  'crohn refractario',
#  'crohnsdisease',
#  'crush syndrome',
#  'cu compleja y refractaria',
#  'cuadro completo de ‘homosexual',
#  'cuadro delirio',
#  'cuadro digestivo',
#  'cuadro gripal',
#  'cuadro psicótico precipitado por estrés',
#  'cuadro pulmonar',
#  'cuadro respiratorio',
#  'cuadro respiratorio inespecífico',
#  'cuadro vírico',
#  'cuadros catarrales en vías altas',
#  'cuadros pseudocatarrales',
#  'cuadros psicóticos',
#  'cuerpos extraños',
#  'culebrilla',
#  'cuperosis',
#  'cushing',
#  'cystic fibrosis',
#  'cysticfibrosis',
#  'çardiaca',
#  'damage the brain',
#  'daño a los riñones',
#  'daño a tus ojos',
#  'daño al cerebro',
#  'daño al corazón',
#  'daño articular y tendinoso',
#  'daño cerebral',
#  'daño cerebral adquirido',
#  'daño cerebral adquirido infantil',
#  'daño cognitivo',
#  'daño de la obesidad',
#  'daño en el cerebro',
#  'daño en el tejido',
#  'daño en su hígado',
#  'daño irreversible',
#  'daño irreversible del nervio óptico',
#  'daño nervioso',
#  'daño neurológico',
#  'daño neurológico grave',
#  'daño permanente en el sistema nervioso',
#  'daño psicológico',
#  'daño pulmonar',
#  'daño renal',
#  'daño renal agudo',
#  'daño renal causado por el lupus',
#  'daño renal y hepático',
#  'daño solar',
#  'daño sufrido en ',
#  'daño tisular extenso, especialmente en los pulmones',
#  'daño tubular agudo',
#  'daño vascular',
#  'dañocerebral',
#  'daños cerebrales',
#  'daños en nervios y neuronas',
#  'dbt 1',
#  'debilidad ósea',
#  'declive mental',
#  'dedos covid',
#  'defectos congenitos',
#  'deficiencia de colágeno',
#  'deficiencia de hierro',
#  'deficiencia pulmonar',
#  'deficiencias de la coagulación',
#  'deficiencias visuales',
#  'deficit de subclases de igg',
#  'deformaciones',
#  'deformidad de la boca',
#  'deformidad tipo cam',
#  'deformidades lumbares',
#  'deformidades severas de extremidades inferiores',
#  'degeneracionmacular',
#  'degeneración macular',
#  'degeneración macular asociada a la edad',
#  'degeneración o desgaste de la articulación',
#  'degeneración precoz',
#  'degeneración tisular',
#  'degenerativas',
#  'deglutición',
#  'delirio tembloroso',
#  'delirios',
#  'delirium',
#  'delirium tremens',
#  'delirum',
#  ...]

# %%
len(diseases_from_tweets)
# Out:
# 4357

# %%
# Reading of "official" disease names (according to IDC-10 / CIE-10 standard) from CSV file

cie = pd.read_csv('Input/Listado_enfermedades_CIE-10.csv')
cie.head()
# Out:
#       code code_0 code_1 code_2 code_3 code_4  \
# 0  A00-B99    NaN    NaN    NaN    NaN    NaN
# 1  C00-D49    NaN    NaN    NaN    NaN    NaN
# 2  D50-D89    NaN    NaN    NaN    NaN    NaN
# 3  E00-E89    NaN    NaN    NaN    NaN    NaN
# 4  F01-F99    NaN    NaN    NaN    NaN    NaN
#
#                                          description  level        source
# 0    Ciertas enfermedades infecciosas y parasitarias      0  icdcode.info
# 1                               Tumores [neoplasias]      0  icdcode.info
# 2  Enfermedades de la sangre y de los órganos hem...      0  icdcode.info
# 3  Enfermedades endocrinas, nutricionales y metab...      0  icdcode.info
# 4           Trastornos mentales y del comportamiento      0  icdcode.info

# %%
cie[200:220]
# Out:
#         code   code_0   code_1 code_2 code_3 code_4  \
# 200      H05  H00-H59  H00-H06    NaN    NaN    NaN
# 201      H06  H00-H59  H00-H06    NaN    NaN    NaN
# 202  P75-P78  P00-P96      NaN    NaN    NaN    NaN
# 203  P80-P83  P00-P96      NaN    NaN    NaN    NaN
# 204  P90-P96  P00-P96      NaN    NaN    NaN    NaN
# 205  O60-O75  O00-O9A      NaN    NaN    NaN    NaN
# 206  O80-O84  O00-O9A      NaN    NaN    NaN    NaN
# 207  O85-O92  O00-O9A      NaN    NaN    NaN    NaN
# 208  O94-O99  O00-O9A      NaN    NaN    NaN    NaN
# 209      F40  F01-F99  F40-F48    NaN    NaN    NaN
# 210      F41  F01-F99  F40-F48    NaN    NaN    NaN
# 211      F42  F01-F99  F40-F48    NaN    NaN    NaN
# 212      F43  F01-F99  F40-F48    NaN    NaN    NaN
# 213      F44  F01-F99  F40-F48    NaN    NaN    NaN
# 214      F45  F01-F99  F40-F48    NaN    NaN    NaN
# 215      F48  F01-F99  F40-F48    NaN    NaN    NaN
# 216  N30-N39  N00-N99      NaN    NaN    NaN    NaN
# 217  N40-N51  N00-N99      NaN    NaN    NaN    NaN
# 218  N60-N64  N00-N99      NaN    NaN    NaN    NaN
# 219  N70-N77  N00-N99      NaN    NaN    NaN    NaN
#
#                                            description  level        source
# 200                            Trastornos de la órbita      2  icdcode.info
# 201  Trastornos del aparato lagrimal y de la órbita...      2  icdcode.info
# 202  Trastornos del sistema digestivo del feto y de...      1  icdcode.info
# 203  Afecciones asociadas con la regulación tegumen...      1  icdcode.info
# 204  Otros trastornos originados en el período peri...      1  icdcode.info
# 205    Complicaciones del trabajo de parto y del parto      1  icdcode.info
# 206                                              Parto      1  icdcode.info
# 207  Complicaciones principalmente relacionadas con...      1  icdcode.info
# 208  Otras afecciones obstétricas no clasificadas e...      1  icdcode.info
# 209                     Trastornos fóbicos de ansiedad      2  icdcode.info
# 210                       Otros trastornos de ansiedad      2  icdcode.info
# 211                      Trastorno obsesivo-compulsivo      2  icdcode.info
# 212  Reacción al estrés grave y trastornos de adapt...      2  icdcode.info
# 213            Trastornos disociativos [de conversión]      2  icdcode.info
# 214                            Trastornos somatomorfos      2  icdcode.info
# 215                        Otros trastornos neuróticos      2  icdcode.info
# 216            Otras enfermedades del sistema urinario      1  icdcode.info
# 217   Enfermedades de los órganos genitales masculinos      1  icdcode.info
# 218                              Trastornos de la mama      1  icdcode.info
# 219  Enfermedades inflamatorias de los órganos pélv...      1  icdcode.info

# %%
# Removing Disease Codes from disease description
cie_list1 = [re.sub(r' \([A-Z]\d\d.*', '', disease) for disease in cie.description.to_list()]

# %%
# Generalisation of disease names (e.g., "Other anxiety disorders -> "anxiety disorders")
cie_list2 = [re.sub(r'^Otr[oa]s ', '', disease) for disease in cie_list1]

# %%
# Normalization of disease name
cie_list3 = [normalize_caseless(disease) for disease in cie_list2]

# %%
len(cie_list3)
# Out:
# 14498

# %%
# Prepare final list: merge two original lists,  remove possible duplicates and sort in alphabetical order
diseases = sorted(set(diseases_from_tweets + cie_list3))

# %%
diseases.remove('')

# %%
len(diseases)
# Out:
# 18417

# %%
diseases
# Out:
# ['abcesos intrabdominales',
#  'abdomen agudo',
#  'abertura artificial, no especificada',
#  'aberturas artificiales',
#  'abortadora habitual',
#  'aborto',
#  'aborto espontaneo: completo o no especificado, complicado con infeccion genital y pelviana',
#  'aborto espontaneo: completo o no especificado, complicado por embolia',
#  'aborto espontaneo: completo o no especificado, complicado por hemorragia excesiva o tardia',
#  'aborto espontaneo: completo o no especificado, con otras complicaciones especificadas y las no especificadas',
#  'aborto espontaneo: completo o no especificado, sin complicacion',
#  'aborto espontaneo: incompleto, complicado con infección genital y pelviana',
#  'aborto espontaneo: incompleto, complicado por embolia',
#  'aborto espontaneo: incompleto, complicado por hemorragia excesiva o tardia',
#  'aborto espontaneo: incompleto, con otras complicaciones especificadas y las no especificadas',
#  'aborto espontaneo: incompleto, sin complicacion',
#  'aborto espontáneo',
#  'aborto medico: completo o no especificado, complicado con infeccion genital y pelviana',
#  'aborto medico: completo o no especificado, complicado por embolia',
#  'aborto medico: completo o no especificado, complicado por hemorragia excesiva o tardia',
#  'aborto medico: completo o no especificado, con otras complicaciones especificadas y las no especificadas',
#  'aborto medico: completo o no especificado, sin complicacion',
#  'aborto medico: incompleto, complicado con infección genital y pelviana',
#  'aborto medico: incompleto, complicado por embolia',
#  'aborto medico: incompleto, complicado por hemorragia excesiva o tardia',
#  'aborto medico: incompleto, con otras complicaciones especificadas y las no especificadas',
#  'aborto medico: incompleto, sin complicacion',
#  'aborto médico',
#  'aborto no especificado',
#  'aborto no especificado: completo o no especificado, complicado con infeccion genital y pelviana',
#  'aborto no especificado: completo o no especificado, complicado por embolia',
#  'aborto no especificado: completo o no especificado, complicado por hemorragia excesiva o tardia',
#  'aborto no especificado: completo o no especificado, con otras complicaciones especificadas y las no especificadas',
#  'aborto no especificado: completo o no especificado, sin complicacion',
#  'aborto no especificado: incompleto, complicado con infección genital y pelviana',
#  'aborto no especificado: incompleto, complicado por embolia',
#  'aborto no especificado: incompleto, complicado por hemorragia excesiva o tardia',
#  'aborto no especificado: incompleto, con otras complicaciones especificadas y las no especificadas',
#  'aborto no especificado: incompleto, sin complicacion',
#  'aborto retenido',
#  'abortoperinatal',
#  'abortos',
#  'abortos de primer y segundo trimestre',
#  'abrasión de los dientes',
#  'absceso',
#  'absceso amebiano del cerebro',
#  'absceso amebiano del hígado',
#  'absceso amebiano del pulmón',
#  'absceso anal',
#  'absceso anorrectal',
#  'absceso cerebral feomicótico',
#  'absceso cutáneo, furúnculo y carbunco',
#  'absceso cutáneo, furúnculo y carbunco de glúteos',
#  'absceso cutáneo, furúnculo y carbunco de la cara',
#  'absceso cutáneo, furúnculo y carbunco de miembro',
#  'absceso cutáneo, furúnculo y carbunco de otros sitios',
#  'absceso cutáneo, furúnculo y carbunco de sitio no especificado',
#  'absceso cutáneo, furúnculo y carbunco del cuello',
#  'absceso cutáneo, furúnculo y carbunco del tronco',
#  'absceso de glándula salival',
#  'absceso de la bolsa sinovial',
#  'absceso de la glándula de bartholin',
#  'absceso de la mama asociado con el parto',
#  'absceso de la próstata',
#  'absceso de las regiones anal y rectal',
#  'absceso de vaina tendinosa',
#  'absceso del bazo',
#  'absceso del hígado',
#  'absceso del intestino',
#  'absceso del mediastino',
#  'absceso del oído externo',
#  'absceso del pulmón con neumonía',
#  'absceso del pulmón sin neumonía',
#  'absceso del pulmón y del mediastino',
#  'absceso del timo',
#  'absceso dental',
#  'absceso extradural y subdural, no especificado',
#  'absceso intraesfinteriano',
#  'absceso isquiorrectal',
#  'absceso periamigdalino',
#  'absceso periapical con fístula',
#  'absceso periapical sin fístula',
#  'absceso rectal',
#  'absceso renal y perirrenal',
#  'absceso retrofaríngeo y parafaríngeo',
#  'absceso uretral',
#  'absceso vulvar',
#  'absceso y granuloma intracraneal',
#  'absceso y granuloma intracraneal e intrarraquídeo',
#  'absceso y granuloma intracraneal e intrarraquídeo en enfermedades clasificadas en otra parte',
#  'absceso y granuloma intrarraquídeo',
#  'absceso y quiste subcutáneo feomicótico',
#  'absceso, furúnculo y ántrax de la nariz',
#  'abscesos',
#  'abscesos abdominales',
#  'abscesos de la faringe',
#  'abscesos dentales por culpa de una caries',
#  'abuso',
#  'abuso a mujeres y niñas con parálisis cerebral',
#  'abuso de alcohol',
#  'abuso de alcohol y tabaco',
#  'abuso de benzos',
#  'abuso de drogas',
#  'abuso de las pantallas',
#  'abuso de sustancias',
#  'abuso de sustancias que no producen dependencia',
#  'abuso del alcohol',
#  'abuso físico',
#  'abuso psicológico',
#  'abuso sexual',
#  'abuso sexual infantil',
#  'acalasia del cardias',
#  'acantamebiasis',
#  'acantosis nigricans',
#  'acantosis nigrocans',
#  'acariasis',
#  'accidente cerebro',
#  'accidente cerebro vascular',
#  'accidente cerebro vascular no especificado',
#  'accidente cerebrovascular',
#  'accidente cerebrovascular isquémico',
#  'accidente de aeronave de motor, con ocupante lesionado',
#  'accidente de aeronave no especificada, con ocupante lesionado',
#  'accidente de aeronave sin motor no especificada, con ocupante lesionado',
#  'accidente de aeronave sin motor, con ocupante lesionado',
#  'accidente de ala delta, con ocupante lesionado',
#  'accidente de embarcacion que causa ahogamiento y sumersion: balsa inflable (sin motor)',
#  'accidente de embarcacion que causa ahogamiento y sumersion: barco de pasajeros',
#  'accidente de embarcacion que causa ahogamiento y sumersion: barco mercante',
#  'accidente de embarcacion que causa ahogamiento y sumersion: bote de pesca',
#  'accidente de embarcacion que causa ahogamiento y sumersion: canoa o kayak',
#  'accidente de embarcacion que causa ahogamiento y sumersion: esqui acuatico',
#  'accidente de embarcacion que causa ahogamiento y sumersion: otro vehiculo acuatico con motor',
#  'accidente de embarcacion que causa ahogamiento y sumersion: otro vehiculo acuatico sin motor',
#  'accidente de embarcacion que causa ahogamiento y sumersion: vehiculo acuatico no especificado',
#  'accidente de embarcacion que causa ahogamiento y sumersion: velero',
#  'accidente de embarcacion que causa otros tipos de traumatismo: balsa inflable (sin motor)',
#  'accidente de embarcacion que causa otros tipos de traumatismo: barco de pasajeros',
#  'accidente de embarcacion que causa otros tipos de traumatismo: barco mercante',
#  'accidente de embarcacion que causa otros tipos de traumatismo: bote de pesca',
#  'accidente de embarcacion que causa otros tipos de traumatismo: canoa o kayak',
#  'accidente de embarcacion que causa otros tipos de traumatismo: esqui acuatico',
#  'accidente de embarcacion que causa otros tipos de traumatismo: otro vehiculo acuatico con motor',
#  'accidente de embarcacion que causa otros tipos de traumatismo: otro vehiculo acuatico sin motor',
#  'accidente de embarcacion que causa otros tipos de traumatismo: vehiculo acuatico no especificado',
#  'accidente de embarcacion que causa otros tipos de traumatismo: velero',
#  'accidente de embarcación que causa ahogamiento y sumersión',
#  'accidente de embarcación que causa otros tipos de traumatismo',
#  'accidente de globo aerostático, con ocupante lesionado',
#  'accidente de helicóptero con ocupante lesionado',
#  'accidente de nave espacial, con ocupante lesionado',
#  'accidente de otras aeronaves sin motor, con ocupante lesionado',
#  'accidente de otras aeronaves, con ocupante lesionado',
#  'accidente de otros vehículos aéreos de alas fijas, privados, con ocupante lesionado',
#  'accidente de planeador (sin motor), con ocupante lesionado',
#  'accidente de planeador ultra liviano, micro liviano o motorizado, con ocupante lesionado',
#  'accidente de transporte no especificado',
#  'accidente de tránsito de tipo especificado, pero donde se desconoce el modo de transporte de la víctima',
#  'accidente de vehículo aéreo de alas fijas, comercial, con ocupante lesionado',
#  'accidente de vehículo de motor o sin motor, tipo de vehículo no especificado',
#  'accidente en una embarcacion, sin accidente a la embarcacion, que no causa ahogamiento o sumersion: balsa inflable (sin motor)',
#  'accidente en una embarcacion, sin accidente a la embarcacion, que no causa ahogamiento o sumersion: barco de pasajeros',
#  'accidente en una embarcacion, sin accidente a la embarcacion, que no causa ahogamiento o sumersion: barco mercante',
#  'accidente en una embarcacion, sin accidente a la embarcacion, que no causa ahogamiento o sumersion: bote de pesca',
#  'accidente en una embarcacion, sin accidente a la embarcacion, que no causa ahogamiento o sumersion: canoa o kayak',
#  'accidente en una embarcacion, sin accidente a la embarcacion, que no causa ahogamiento o sumersion: esqui acuatico',
#  'accidente en una embarcacion, sin accidente a la embarcacion, que no causa ahogamiento o sumersion: otro vehiculo acuatico con motor',
#  'accidente en una embarcacion, sin accidente a la embarcacion, que no causa ahogamiento o sumersion: otro vehiculo acuatico sin motor',
#  'accidente en una embarcacion, sin accidente a la embarcacion, que no causa ahogamiento o sumersion: vehiculo acuatico no especificado',
#  'accidente en una embarcacion, sin accidente a la embarcacion, que no causa ahogamiento o sumersion: velero',
#  'accidente en una embarcación, sin accidente a la embarcación, que no causa ahogamiento o sumersión',
#  'accidente no de tránsito de tipo especificado, pero donde se desconoce el modo de transporte de la víctima',
#  'accidente vascular encefálico agudo, no especificado como hemorrágico o isquémico',
#  'accidentes',
#  'accidentes cerebrovasculares',
#  'accidentes de transporte aéreo especificados',
#  'accidentes de transporte aéreo y espacial',
#  'accidentes de transporte aéreo, no clasificados en otra parte',
#  'accidentes de transporte especificados',
#  'accidentes de transporte por agua',
#  'accidentes de transporte por agua, y los no especificados',
#  'accidentes de transporte por agua, y los no especificados. otro vehiculo acuatico sin motor',
#  'accidentes de transporte por agua, y los no especificados: balsa inflable (sin motor)',
#  'accidentes de transporte por agua, y los no especificados: barco de pasajeros',
#  'accidentes de transporte por agua, y los no especificados: barco mercante',
#  'accidentes de transporte por agua, y los no especificados: bote de pesca',
#  'accidentes de transporte por agua, y los no especificados: canoa o kayak',
#  'accidentes de transporte por agua, y los no especificados: esqui acuatico',
#  'accidentes de transporte por agua, y los no especificados: otro vehiculo acuatico con motor',
#  'accidentes de transporte por agua, y los no especificados: vehiculo acuatico no especificado',
#  'accidentes de transporte por agua, y los no especificados: velero',
#  'accidentes de transporte terrestre',
#  'accidentes de transporte, y los no especificados',
#  'accidentes laborales',
#  'accidentes que obstruyen la respiración',
#  'accidentes vasculares',
#  'accreta',
#  'acetonuria',
#  'acidez',
#  'acido lisérgico [lsd]',
#  'acidosis',
#  'acidosis hipercl',
#  'acidosis hiperclorémica',
#  'acidosis metabólica',
#  'acidosis metabólica tardía del recién nacido',
#  'acné',
#  'acné conglobado',
#  'acné excoriado de la mujer joven',
#  'acné grave',
#  'acné infantil',
#  'acné queloide',
#  'acné tropical',
#  'acné varioliforme',
#  'acné vulgar',
#  'acné, no especificado',
#  'acnés',
#  'acondrogénesis',
#  'acondroplasia',
#  'acortamiento del tendón de aquiles (adquirido)',
#  'acretismo placentario',
#  'acrodermatitis continua',
#  'acrodermatitis crónica atrófica',
#  'acrodermatitis papular infantil [giannotti–crosti]',
#  'acromegalia y gigantismo hipofisario',
#  'actinomicetoma',
#  'actinomicosis',
#  'actinomicosis abdominal',
#  'actinomicosis cervicofacial',
#  'actinomicosis pulmonar',
#  'actinomicosis, sin otra especificación',
#  'actos e ideas obsesivas mixtos',
#  'acumulación atípica de grasa en las extremidades',
#  'acv criptogénico',
#  'acv en ganglios basales',
#  'acv isquémicos',
#  'acv lacunar',
#  'adenitis',
#  'adenocarcinoma',
#  'adenocarcinoma de pulmón',
#  'adenomegalia',
#  'adenomegalia generalizada',
#  'adenomegalia localizada',
#  'adenomegalia, no especificada',
#  'adenomiosis',
#  'adenopatías',
#  'adenopatías biliares bilaterales',
#  'adenovirus como causa de enfermedades clasificadas en otros capítulos',
#  'adherencias [bridas] intestinales con obstrucción',
#  'adherencias peritoneales',
#  'adherencias peritoneales pélvicas consecutivas a procedimientos',
#  'adherencias peritoneales pélvicas femeninas',
#  'adherencias postoperatorias de la vagina',
#  'adherencias y desgarros del iris y del cuerpo ciliar',
#  'adiccion',
#  'adicciones',
#  'adicciones ',
#  'adicción',
#  'adicción a la cocaína y la heroína',
#  'adicción a las redes sociales',
#  'adicción a lo digital',
#  'adicción al tabaco',
#  'adicción como alcohol',
#  'adictos a alguna sustancia',
#  'adiestramiento ortóptico',
#  'adiposidad localizada',
#  'adolescencia y ',
#  'advp',
#  'afaquia',
#  'afaquia congénita',
#  'afasia',
#  'afasia adquirida con epilepsia [landau-kleffner]',
#  'afasiaprogresivaprimaria',
#  'afasias',
#  'afasias progresivas',
#  'afecciones alveolares y alveoloparietales',
#  'afecciones asociadas con la regulación tegumentaria y la temperatura del feto y del recién nacido',
#  'afecciones de la piel específicas del feto y del recién nacido',
#  'afecciones de la pleura',
#  'afecciones degenerativas del globo ocular',
#  'afecciones del corazón',
#  'afecciones eritematosas',
#  'afecciones eritematosas especificadas',
#  'afecciones especificadas asociadas con los órganos genitales femeninos y el ciclo menstrual',
#  'afecciones especificadas de la piel, propias del feto y del recién nacido',
#  'afecciones especificadas de la pleura',
#  'afecciones especificadas de los dientes y de sus estructuras de sostén',
#  'afecciones especificadas originadas en el período perinatal',
#  'afecciones exoftálmicas',
#  'afecciones hemorrágicas especificadas',
#  'afecciones inflamatorias de la vagina y de la vulva',
#  'afecciones inflamatorias de los maxilares',
#  'afecciones neurológicas',
#  'afecciones no especificadas asociadas con los órganos genitales femeninos y el ciclo menstrual',
#  'afecciones no infecciosas del pabellón auditivo',
#  'afecciones obstétricas no clasificadas en otra parte',
#  'afecciones oculares',
#  'afecciones originadas en el período perinatal',
#  'afecciones relacionadas con el enfisema intersticial, originadas en el período perinatal',
#  'afecciones relacionadas con la poliarteritis nudosa',
#  'afecciones respiratorias',
#  'afecciones respiratorias agudas y subagudas debidas a inhalación de gases, humos, vapores y sustancias químicas',
#  'afecciones respiratorias crónicas debidas a inhalación de gases, humos, vapores y sustancias químicas',
#  'afecciones respiratorias debidas a agentes externos no especificados',
#  'afecciones respiratorias debidas a inhalación de gases, humos, vapores y sustancias químicas',
#  'afecciones respiratorias debidas a otros agentes externos',
#  'afecciones respiratorias debidas a otros agentes externos especificados',
#  'afecciones supurativas y necróticas de las vías respiratorias inferiores',
#  'afecciones tubulares y tubulointersticiales inducidas por drogas y por metales pesados',
#  'afección broncopulmonar',
#  'afección cardíaca',
#  'afección eritematosa, no especificada',
#  'afección hemorrágica, no especificada',
#  'afección no especificada de la piel, propia del feto y del recién nacido',
#  'afección no especificada originada en el período perinatal',
#  'afección nosocomial',
#  'afección pleural, no especificada',
#  'afección relacionada con el estilo de vida',
#  'afección relacionada con el trabajo',
#  'afección relacionada con la contaminación ambiental',
#  'afección respiratoria no especificada del recién nacido',
#  'afección respiratoria no especificada, debida a inhalación de gases, humos, vapores y sustancias químicas',
#  'afectación articular',
#  'afectación de la retina',
#  'afectación en el sistema de conducción cardiaco',
#  'afonía',
#  'aftas',
#  'aftas bucales',
#  'aftasbucales',
#  'agalactia',
#  'agenesia del pulmón',
#  'agenesia del sexto par',
#  'agenesia del uréter',
#  'agenesia o hipoplasia de la nariz',
#  'agenesia renal y otras malformaciones hipoplásicas del riñón',
#  'agenesia renal, bilateral',
#  'agenesia renal, sin otra especificación',
#  'agenesia renal, unilateral',
#  'agenesia y aplasia del cuello uterino',
#  'agenesia y aplasia del útero',
#  'agenesia, aplasia e hipoplasia de la vesícula biliar',
#  'agenesia, aplasia e hipoplasia del páncreas',
#  'agentes anticolinesterasa',
#  'agentes bacterianos como causa de enfermedades clasificadas en otros capítulos',
#  'agentes bacterianos especificados como causa de enfermedades clasificadas en otros capítulos',
#  'agentes de acción central y bloqueadores neuronales adrenérgicos, no clasificados en otra parte',
#  'agentes del equilibrio hidrolítico, electrolítico y calórico',
#  'agentes diagnósticos',
#  'agentes no especificados que afectan principalmente el sistema gastrointestinal',
#  'agentes principalmente sistémicos y hematológicos',
#  'agentes principalmente sistémicos y hematológicos, no especificados',
#  'agentes que afectan principalmente el sistema gastrointestinal',
#  'agentes tópicos',
#  'agentes tópicos, no especificados',
#  'agentes virales como causa de enfermedades clasificadas en otros capítulos',
#  'agentes y los no especificados de acción principal sobre el sistema respiratorio',
#  'agentes y los no especificados que afectan principalmente el sistema cardiovascular',
#  'agnosia',
#  'agonistas, predominantemente alfa-adrenérgicos, no clasificados en otra parte',
#  'agonistas, predominantemente beta-adrenérgicos, no clasificados en otra parte',
#  'agorafobia',
#  'agotamiento debido a esfuerzo excesivo',
#  'agotamiento debido a exposición a la intemperie',
#  'agotamiento por calor debido a depleción de sal',
#  'agotamiento por calor, anhidrótico',
#  'agotamiento por calor, no especificado',
#  'agrandamiento de los ventrículos cerebrales',
#  'agrandamiento e hipertrofia de las uñas',
#  'agranulocitosis',
#  'agresion con disparo de arma corta: area industrial y de la construccion',
#  'agresion con disparo de arma corta: areas de deporte y atletismo',
#  'agresion con disparo de arma corta: calles y carreteras',
#  'agresion con disparo de arma corta: comercio y areas de servicio',
#  'agresion con disparo de arma corta: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con disparo de arma corta: granja',
#  'agresion con disparo de arma corta: institucion residencial',
#  'agresion con disparo de arma corta: lugar no especificado',
#  'agresion con disparo de arma corta: otro lugar especificado',
#  'agresion con disparo de arma corta: vivienda',
#  'agresion con disparo de otras armas de fuego, y las no especificadas: area industrial y de la construccion',
#  'agresion con disparo de otras armas de fuego, y las no especificadas: areas de deporte y atletismo',
#  'agresion con disparo de otras armas de fuego, y las no especificadas: calles y carreteras',
#  'agresion con disparo de otras armas de fuego, y las no especificadas: comercio y areas de servicio',
#  'agresion con disparo de otras armas de fuego, y las no especificadas: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con disparo de otras armas de fuego, y las no especificadas: granja',
#  'agresion con disparo de otras armas de fuego, y las no especificadas: institucion residencial',
#  'agresion con disparo de otras armas de fuego, y las no especificadas: lugar no especificado',
#  'agresion con disparo de otras armas de fuego, y las no especificadas: otro lugar especificado',
#  'agresion con disparo de otras armas de fuego, y las no especificadas: vivienda',
#  'agresion con disparo de rifle, escopeta y arma larga: area industrial y de la construccion',
#  'agresion con disparo de rifle, escopeta y arma larga: areas de deporte y atletismo',
#  'agresion con disparo de rifle, escopeta y arma larga: calles y carreteras',
#  'agresion con disparo de rifle, escopeta y arma larga: comercio y areas de servicio',
#  'agresion con disparo de rifle, escopeta y arma larga: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con disparo de rifle, escopeta y arma larga: granja',
#  'agresion con disparo de rifle, escopeta y arma larga: institucion residencial',
#  'agresion con disparo de rifle, escopeta y arma larga: lugar no especificado',
#  'agresion con disparo de rifle, escopeta y arma larga: otro lugar especificado',
#  'agresion con disparo de rifle, escopeta y arma larga: vivienda',
#  'agresion con drogas, medicamentos y sustancias biologicas: area industrial y de la construccion',
#  'agresion con drogas, medicamentos y sustancias biologicas: areas de deporte y atletismo',
#  'agresion con drogas, medicamentos y sustancias biologicas: calles y carreteras',
#  'agresion con drogas, medicamentos y sustancias biologicas: comercio y areas de servicio',
#  'agresion con drogas, medicamentos y sustancias biologicas: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con drogas, medicamentos y sustancias biologicas: granja',
#  'agresion con drogas, medicamentos y sustancias biologicas: institucion residencial',
#  'agresion con drogas, medicamentos y sustancias biologicas: lugar no especificado',
#  'agresion con drogas, medicamentos y sustancias biologicas: otro lugar especificado',
#  'agresion con drogas, medicamentos y sustancias biologicas: vivienda',
#  'agresion con fuerza corporal: area industrial y de la construccion',
#  'agresion con fuerza corporal: areas de deporte y atletismo',
#  'agresion con fuerza corporal: calles y carreteras',
#  'agresion con fuerza corporal: comercio y area de servicios',
#  'agresion con fuerza corporal: escuelas, otras instituciones y areas administrativas',
#  'agresion con fuerza corporal: granja',
#  'agresion con fuerza corporal: institucion residencial',
#  'agresion con fuerza corporal: lugar no especificado',
#  'agresion con fuerza corporal: otro lugar especificado',
#  'agresion con fuerza corporal: vivienda',
#  'agresion con gases y vapores: area industrial y de la construccion',
#  'agresion con gases y vapores: areas de deporte y atletismo',
#  'agresion con gases y vapores: calles y carreteras',
#  'agresion con gases y vapores: comercio y areas de servicio',
#  'agresion con gases y vapores: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con gases y vapores: granja',
#  'agresion con gases y vapores: institucion residencial',
#  'agresion con gases y vapores: lugar no especificado',
#  'agresion con gases y vapores: otro lugar especificado',
#  'agresion con gases y vapores: vivienda',
#  'agresion con humo, fuego y llamas: area industrial y de la construccion',
#  'agresion con humo, fuego y llamas: areas de deporte y atletismo',
#  'agresion con humo, fuego y llamas: calles y carreteras',
#  'agresion con humo, fuego y llamas: comercio y areas de servicio',
#  'agresion con humo, fuego y llamas: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con humo, fuego y llamas: granja',
#  'agresion con humo, fuego y llamas: institucion residencial',
#  'agresion con humo, fuego y llamas: lugar no especificado',
#  'agresion con humo, fuego y llamas: otro lugar especificado',
#  'agresion con humo, fuego y llamas: vivienda',
#  'agresion con material explosivo: area industrial y de la construccion',
#  'agresion con material explosivo: areas de deporte y atletismo',
#  'agresion con material explosivo: calles y carreteras',
#  'agresion con material explosivo: comercio y areas de servicio',
#  'agresion con material explosivo: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con material explosivo: granja',
#  'agresion con material explosivo: institucion residencial',
#  'agresion con material explosivo: lugar no especificado',
#  'agresion con material explosivo: otro lugar especificado',
#  'agresion con material explosivo: vivienda',
#  'agresion con objeto cortante: area industrial y de la construccion',
#  'agresion con objeto cortante: areas de deporte y atletismo',
#  'agresion con objeto cortante: calles y carreteras',
#  'agresion con objeto cortante: comercio y areas de servicio',
#  'agresion con objeto cortante: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con objeto cortante: granja',
#  'agresion con objeto cortante: institucion residencial',
#  'agresion con objeto cortante: lugar no especificado',
#  'agresion con objeto cortante: otro lugar especificado',
#  'agresion con objeto cortante: vivienda',
#  'agresion con objeto romo o sin filo: area industrial y de la construccion',
#  'agresion con objeto romo o sin filo: areas de deporte y atletismo',
#  'agresion con objeto romo o sin filo: calles y carreteras',
#  'agresion con objeto romo o sin filo: comercio y area de servicios',
#  'agresion con objeto romo o sin filo: escuelas otras instituciones y areas administrativas',
#  'agresion con objeto romo o sin filo: granja',
#  'agresion con objeto romo o sin filo: institucion residencial',
#  'agresion con objeto romo o sin filo: lugar no especificado',
#  'agresion con objeto romo o sin filo: otro lugar especificado',
#  'agresion con objeto romo o sin filo: vivienda',
#  'agresion con otros productos quimicos y sustancias nocivas especificadas: area industrial y de la construccion',
#  'agresion con otros productos quimicos y sustancias nocivas especificadas: areas de deporte y atletismo',
#  'agresion con otros productos quimicos y sustancias nocivas especificadas: calles y carreteras',
#  'agresion con otros productos quimicos y sustancias nocivas especificadas: comercio y areas de servicio',
#  'agresion con otros productos quimicos y sustancias nocivas especificadas: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con otros productos quimicos y sustancias nocivas especificadas: granja',
#  'agresion con otros productos quimicos y sustancias nocivas especificadas: institucion residencial',
#  'agresion con otros productos quimicos y sustancias nocivas especificadas: lugar no especificado',
#  'agresion con otros productos quimicos y sustancias nocivas especificadas: otro lugar especificado',
#  'agresion con otros productos quimicos y sustancias nocivas especificadas: vivienda',
#  'agresion con plaguicidas: area industrial y de la construccion',
#  'agresion con plaguicidas: areas de deporte y atletismo',
#  'agresion con plaguicidas: calles y carreteras',
#  'agresion con plaguicidas: comercio y areas de servicio',
#  'agresion con plaguicidas: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con plaguicidas: granja',
#  'agresion con plaguicidas: institucion residencial',
#  'agresion con plaguicidas: lugar no especificado',
#  'agresion con plaguicidas: otro lugar especificado',
#  'agresion con plaguicidas: vivienda',
#  'agresion con productos quimicos y sustancias nocivas no especificadas: area industrial y de la construccion',
#  'agresion con productos quimicos y sustancias nocivas no especificadas: areas de deporte y atletismo',
#  'agresion con productos quimicos y sustancias nocivas no especificadas: calles y carreteras',
#  'agresion con productos quimicos y sustancias nocivas no especificadas: comercio y areas de servicio',
#  'agresion con productos quimicos y sustancias nocivas no especificadas: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con productos quimicos y sustancias nocivas no especificadas: granja',
#  'agresion con productos quimicos y sustancias nocivas no especificadas: institucion residencial',
#  'agresion con productos quimicos y sustancias nocivas no especificadas: lugar no especificado',
#  'agresion con productos quimicos y sustancias nocivas no especificadas: otro lugar especificado',
#  'agresion con productos quimicos y sustancias nocivas no especificadas: vivienda',
#  'agresion con sustancia corrosiva: area industrial y de la construccion',
#  'agresion con sustancia corrosiva: calles y carreteras',
#  'agresion con sustancia corrosiva: comercio y areas de servicio',
#  'agresion con sustancia corrosiva: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con sustancia corrosiva: granja',
#  'agresion con sustancia corrosiva: lugar no especificado',
#  'agresion con sustancia corrosiva: vivienda',
#  'agresion con sustanciacorrosiva: areas de deporte y atletismo',
#  'agresion con sustanciacorrosiva: institucion residencial',
#  'agresion con sustanciacorrosiva: otro lugar especificado',
#  'agresion con vapor de agua, vapores y objetos calientes: area industrial y de la construccion',
#  'agresion con vapor de agua, vapores y objetos calientes: areas de deporte y atletismo',
#  'agresion con vapor de agua, vapores y objetos calientes: calles y carreteras',
#  'agresion con vapor de agua, vapores y objetos calientes: comercio y areas de servicio',
#  'agresion con vapor de agua, vapores y objetos calientes: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion con vapor de agua, vapores y objetos calientes: granja',
#  'agresion con vapor de agua, vapores y objetos calientes: institucion residencial',
#  'agresion con vapor de agua, vapores y objetos calientes: lugar no especificado',
#  'agresion con vapor de agua, vapores y objetos calientes: otro lugar especificado',
#  'agresion con vapor de agua, vapores y objetos calientes: vivienda',
#  'agresion por ahogamiento y sumersion: area industrial y de la construccion',
#  'agresion por ahogamiento y sumersion: areas de deporte y atletismo',
#  'agresion por ahogamiento y sumersion: calles y carreteras',
#  'agresion por ahogamiento y sumersion: comercio y areas de servicio',
#  'agresion por ahogamiento y sumersion: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion por ahogamiento y sumersion: granja',
#  'agresion por ahogamiento y sumersion: institucion residencial',
#  'agresion por ahogamiento y sumersion: lugar no especificado',
#  'agresion por ahogamiento y sumersion: otro lugar especificado',
#  'agresion por ahogamiento y sumersion: vivienda',
#  'agresion por ahorcamiento, estrangulamiento y sofocacion: area industrial y de la construccion',
#  'agresion por ahorcamiento, estrangulamiento y sofocacion: areas de deporte y atletismo',
#  'agresion por ahorcamiento, estrangulamiento y sofocacion: calles y carreteras',
#  'agresion por ahorcamiento, estrangulamiento y sofocacion: comercio y areas de servicio',
#  'agresion por ahorcamiento, estrangulamiento y sofocacion: escuelas, otras instituciones y areas administrativas publicas',
#  'agresion por ahorcamiento, estrangulamiento y sofocacion: granja',
#  'agresion por ahorcamiento, estrangulamiento y sofocacion: institucion residencial',
#  'agresion por ahorcamiento, estrangulamiento y sofocacion: lugar no especificado',
#  'agresion por ahorcamiento, estrangulamiento y sofocacion: otro lugar especificado',
#  'agresion por ahorcamiento, estrangulamiento y sofocacion: vivienda',
#  'agresion por colision de vehiculo de motor: area industrial y de la construccion',
#  'agresion por colision de vehiculo de motor: areas de deporte y atletismo',
#  'agresion por colision de vehiculo de motor: calles y carreteras',
#  'agresion por colision de vehiculo de motor: comercio y area de servicios',
#  'agresion por colision de vehiculo de motor: escuelas, otras instituciones y areas administrativas',
#  'agresion por colision de vehiculo de motor: granja',
#  'agresion por colision de vehiculo de motor: institucion residencial',
#  'agresion por colision de vehiculo de motor: lugar no especificado',
#  'agresion por colision de vehiculo de motor: otro lugar especificado',
#  'agresion por colision de vehiculo de motor: vivienda',
#  'agresion por empujar o colocar a la victima delante de objeto en movimiento: area industrial y de la construccion',
#  'agresion por empujar o colocar a la victima delante de objeto en movimiento: areas de deporte y atletismo',
#  'agresion por empujar o colocar a la victima delante de objeto en movimiento: calles y carreteras',
#  'agresion por empujar o colocar a la victima delante de objeto en movimiento: comercio y area de servicios',
#  'agresion por empujar o colocar a la victima delante de objeto en movimiento: escuelas otras instituciones y areas administrativas',
#  'agresion por empujar o colocar a la victima delante de objeto en movimiento: granja',
#  'agresion por empujar o colocar a la victima delante de objeto en movimiento: institucion residencial',
#  'agresion por empujar o colocar a la victima delante de objeto en movimiento: lugar no especificado',
#  'agresion por empujar o colocar a la victima delante de objeto en movimiento: otro lugar especificado',
#  'agresion por empujar o colocar a la victima delante de objeto en movimiento: vivienda',
#  'agresion por empujon desde un lugar elevado: area industrial y de la construccion',
#  'agresion por empujon desde un lugar elevado: areas de deporte y atletismo',
#  'agresion por empujon desde un lugar elevado: calles y carreteras',
#  'agresion por empujon desde un lugar elevado: comercio y area de servicios',
#  'agresion por empujon desde un lugar elevado: escuelas otras instituciones y areas administrativas',
#  'agresion por empujon desde un lugar elevado: granja',
#  'agresion por empujon desde un lugar elevado: institucion residencial',
#  'agresion por empujon desde un lugar elevado: lugar no especificado',
#  'agresion por empujon desde un lugar elevado: otro lugar especificado',
#  'agresion por empujon desde un lugar elevado: vivienda',
#  'agresion por medios no especificados: area industrial y de la construccion',
#  'agresion por medios no especificados: areas de deporte y atletismo',
#  'agresion por medios no especificados: calles y carreteras',
#  'agresion por medios no especificados: comercio y area de servicios',
#  'agresion por medios no especificados: escuelas otras instituciones y areas administrativas',
#  'agresion por medios no especificados: granja',
#  'agresion por medios no especificados: institucion residencial',
#  'agresion por medios no especificados: lugar no especificado',
#  'agresion por medios no especificados: otro lugar especificado',
#  'agresion por medios no especificados: vivienda',
#  'agresion por otros medios especificados: area industrial y de la construccion',
#  'agresion por otros medios especificados: areas de deporte y atletismo',
#  'agresion por otros medios especificados: calles y carreteras',
#  'agresion por otros medios especificados: comercio y area de servicios',
#  'agresion por otros medios especificados: escuelas, otras instituciones y areas administrativas',
#  'agresion por otros medios especificados: granja',
#  'agresion por otros medios especificados: institucion residencial',
#  'agresion por otros medios especificados: lugar no especificado',
#  'agresion por otros medios especificados: otro lugar especificado',
#  'agresion por otros medios especificados: vivienda',
#  'agresion sexual con fuerza corporal: area industrial y de la construccion',
#  'agresion sexual con fuerza corporal: areas de deporte y atletismo',
#  'agresion sexual con fuerza corporal: calles y carreteras',
#  'agresion sexual con fuerza corporal: comercio y area de servicios',
#  'agresion sexual con fuerza corporal: escuelas, otras instituciones y areas administrativas',
#  'agresion sexual con fuerza corporal: granja',
#  'agresion sexual con fuerza corporal: institucion residencial',
#  'agresion sexual con fuerza corporal: lugar no especificado',
#  'agresion sexual con fuerza corporal: otro lugar especificado',
#  'agresion sexual con fuerza corporal: vivienda',
#  'agresiones',
#  'agresión con disparo de arma corta',
#  'agresión con disparo de otras armas de fuego, y las no especificadas',
#  'agresión con disparo de rifle, escopeta y arma larga',
#  'agresión con drogas, medicamentos y sustancias biológicas',
#  'agresión con fuerza corporal',
#  'agresión con gases y vapores',
#  'agresión con humo, fuego y llamas',
#  'agresión con material explosivo',
#  'agresión con objeto cortante',
#  'agresión con objeto romo o sin filo',
#  'agresión con otros productos químicos y sustancias nocivas especificadas',
#  'agresión con plaguicidas',
#  'agresión con productos químicos y sustancias nocivas no especificadas',
#  'agresión con sustancia corrosiva',
#  'agresión con vapor de agua, vapores y objetos calientes',
#  'agresión por ahogamiento y sumersión',
#  'agresión por ahorcamiento, estrangulamiento y sofocación',
#  'agresión por colisión de vehículo de motor',
#  'agresión por empujar o colocar a la víctima delante de objeto en movimiento',
#  'agresión por empujón desde un lugar elevado',
#  'agresión por medios no especificados',
#  'agresión por otros medios especificados',
#  'agresión sexual con fuerza corporal',
#  'ahogamiento y sumersion consecutivos a caida en la bañera: area industrial y de la construccion',
#  'ahogamiento y sumersion consecutivos a caida en la bañera: areas de deporte y atletismo',
#  'ahogamiento y sumersion consecutivos a caida en la bañera: calles y carreteras',
#  'ahogamiento y sumersion consecutivos a caida en la bañera: comercio y areas de servicio',
#  'ahogamiento y sumersion consecutivos a caida en la bañera: escuelas, otras instituciones y areas administrativas publicas',
#  'ahogamiento y sumersion consecutivos a caida en la bañera: granja',
#  'ahogamiento y sumersion consecutivos a caida en la bañera: institucion residencial',
#  'ahogamiento y sumersion consecutivos a caida en la bañera: lugar no especificado',
#  'ahogamiento y sumersion consecutivos a caida en la bañera: otro lugar especificado',
#  'ahogamiento y sumersion consecutivos a caida en la bañera: vivienda',
#  'ahogamiento y sumersion consecutivos a caida en una piscina: area industrial y de la construccion',
#  'ahogamiento y sumersion consecutivos a caida en una piscina: areas de deporte y atletismo',
#  'ahogamiento y sumersion consecutivos a caida en una piscina: calles y carreteras',
#  'ahogamiento y sumersion consecutivos a caida en una piscina: comercio y areas de servicio',
#  'ahogamiento y sumersion consecutivos a caida en una piscina: escuelas, otras instituciones y areas administrativas publicas',
#  'ahogamiento y sumersion consecutivos a caida en una piscina: granja',
#  'ahogamiento y sumersion consecutivos a caida en una piscina: institucion residencial',
#  'ahogamiento y sumersion consecutivos a caida en una piscina: lugar no especificado',
#  'ahogamiento y sumersion consecutivos a caida en una piscina: otro lugar especificado',
#  'ahogamiento y sumersion consecutivos a caida en una piscina: vivienda',
#  'ahogamiento y sumersion mientras se esta en aguas naturales: area industrial y de la construccion',
#  'ahogamiento y sumersion mientras se esta en aguas naturales: areas de deporte y atletismo',
#  'ahogamiento y sumersion mientras se esta en aguas naturales: calles y carreteras',
#  'ahogamiento y sumersion mientras se esta en aguas naturales: comercio y areas de servicio',
#  'ahogamiento y sumersion mientras se esta en aguas naturales: escuelas, otras instituciones y areas administrativas publicas',
#  'ahogamiento y sumersion mientras se esta en aguas naturales: granja',
#  'ahogamiento y sumersion mientras se esta en aguas naturales: institucion residencial',
#  'ahogamiento y sumersion mientras se esta en aguas naturales: lugar no especificado',
#  'ahogamiento y sumersion mientras se esta en aguas naturales: otro lugar especificado',
#  'ahogamiento y sumersion mientras se esta en aguas naturales: vivienda',
#  'ahogamiento y sumersion mientras se esta en la bañera: area industrial y de la construccion',
#  'ahogamiento y sumersion mientras se esta en la bañera: areas de deporte y atletismo',
#  'ahogamiento y sumersion mientras se esta en la bañera: calles y carreteras',
#  'ahogamiento y sumersion mientras se esta en la bañera: comercio y areas de servicio',
#  'ahogamiento y sumersion mientras se esta en la bañera: escuelas, otras instituciones y areas administrativas publicas',
#  'ahogamiento y sumersion mientras se esta en la bañera: granja',
#  'ahogamiento y sumersion mientras se esta en la bañera: institucion residencial',
#  'ahogamiento y sumersion mientras se esta en la bañera: lugar no especificado',
#  'ahogamiento y sumersion mientras se esta en la bañera: otro lugar especificado',
#  'ahogamiento y sumersion mientras se esta en la bañera: vivienda',
#  'ahogamiento y sumersion mientras se esta en una piscina: area industrial y de la construccion',
#  'ahogamiento y sumersion mientras se esta en una piscina: areas de deporte y atletismo',
#  'ahogamiento y sumersion mientras se esta en una piscina: calles y carreteras',
#  'ahogamiento y sumersion mientras se esta en una piscina: comercio y areas de servicio',
#  'ahogamiento y sumersion mientras se esta en una piscina: escuelas, otras instituciones y areas administrativas publicas',
#  'ahogamiento y sumersion mientras se esta en una piscina: granja',
#  'ahogamiento y sumersion mientras se esta en una piscina: institucion residencial',
#  'ahogamiento y sumersion mientras se esta en una piscina: lugar no especificado',
#  'ahogamiento y sumersion mientras se esta en una piscina: otro lugar especificado',
#  'ahogamiento y sumersion mientras se esta en una piscina: vivienda',
#  'ahogamiento y sumersion no especificados: area industrial y de la construccion',
#  'ahogamiento y sumersion no especificados: areas de deporte y atletismo',
#  'ahogamiento y sumersion no especificados: calles y carreteras',
#  'ahogamiento y sumersion no especificados: comercio y areas de servicio',
#  'ahogamiento y sumersion no especificados: escuelas, otras instituciones y areas administrativas publicas',
#  'ahogamiento y sumersion no especificados: granja',
#  'ahogamiento y sumersion no especificados: institucion residencial',
#  'ahogamiento y sumersion no especificados: lugar no especificado',
#  'ahogamiento y sumersion no especificados: otro lugar especificado',
#  'ahogamiento y sumersion no especificados: vivienda',
#  'ahogamiento y sumersion posterior a caida en aguas naturales: area industrial y de la construccion',
#  'ahogamiento y sumersion posterior a caida en aguas naturales: areas de deporte y atletismo',
#  'ahogamiento y sumersion posterior a caida en aguas naturales: calles y carreteras',
#  'ahogamiento y sumersion posterior a caida en aguas naturales: comercio y areas de servicio',
#  'ahogamiento y sumersion posterior a caida en aguas naturales: escuelas, otras instituciones y areas administrativas publicas',
#  'ahogamiento y sumersion posterior a caida en aguas naturales: granja',
#  'ahogamiento y sumersion posterior a caida en aguas naturales: institucion residencial',
#  'ahogamiento y sumersion posterior a caida en aguas naturales: lugar no especificado',
#  'ahogamiento y sumersion posterior a caida en aguas naturales: otro lugar especificado',
#  'ahogamiento y sumersion posterior a caida en aguas naturales: vivienda',
#  'ahogamiento y sumersion relacionados con transporte por agua, sin accidente a la embarcacion: balsa inflable (sin motor)',
#  'ahogamiento y sumersion relacionados con transporte por agua, sin accidente a la embarcacion: barco de pasajeros',
#  'ahogamiento y sumersion relacionados con transporte por agua, sin accidente a la embarcacion: barco mercante',
#  'ahogamiento y sumersion relacionados con transporte por agua, sin accidente a la embarcacion: bote de pesca',
#  'ahogamiento y sumersion relacionados con transporte por agua, sin accidente a la embarcacion: canoa o kayak',
#  'ahogamiento y sumersion relacionados con transporte por agua, sin accidente a la embarcacion: esqui acuatico',
#  'ahogamiento y sumersion relacionados con transporte por agua, sin accidente a la embarcacion: otro vehiculo acuatico con motor',
#  'ahogamiento y sumersion relacionados con transporte por agua, sin accidente a la embarcacion: otro vehiculo acuatico sin motor',
#  'ahogamiento y sumersion relacionados con transporte por agua, sin accidente a la embarcacion: vehiculo acuatico no especificado',
#  'ahogamiento y sumersion relacionados con transporte por agua, sin accidente a la embarcacion: velero',
#  'ahogamiento y sumersion, de intencion no determinada: area industrial y de la construccion',
#  'ahogamiento y sumersion, de intencion no determinada: areas de deporte y atletismo',
#  'ahogamiento y sumersion, de intencion no determinada: calles y carreteras',
#  'ahogamiento y sumersion, de intencion no determinada: comercio y area de servicios',
#  'ahogamiento y sumersion, de intencion no determinada: escuelas otras instituciones y areas administrativas',
#  'ahogamiento y sumersion, de intencion no determinada: granja',
#  'ahogamiento y sumersion, de intencion no determinada: institucion residencial',
#  'ahogamiento y sumersion, de intencion no determinada: lugar no especificado',
#  'ahogamiento y sumersion, de intencion no determinada: otro lugar especificado',
#  'ahogamiento y sumersion, de intencion no determinada: vivienda',
#  'ahogamiento y sumersión accidentales',
#  'ahogamiento y sumersión consecutivos a caída en la bañera',
#  'ahogamiento y sumersión consecutivos a caída en una piscina',
#  'ahogamiento y sumersión mientras se está en aguas naturales',
#  'ahogamiento y sumersión mientras se está en la bañera',
#  'ahogamiento y sumersión mientras se está en una piscina',
#  'ahogamiento y sumersión no especificados',
#  'ahogamiento y sumersión no mortal',
#  'ahogamiento y sumersión posterior a caída en aguas naturales',
#  'ahogamiento y sumersión relacionados con transporte por agua, sin accidente a la embarcación',
#  'ahogamiento y sumersión, de intención no determinada',
#  'ahogamientos y sumersiones especificados',
#  'ahogamientos y sumersiones especificados: area industrial y de la construccion',
#  'ahogamientos y sumersiones especificados: areas de deporte y atletismo',
#  'ahogamientos y sumersiones especificados: calles y carreteras',
#  'ahogamientos y sumersiones especificados: comercio y areas de servicio',
#  'ahogamientos y sumersiones especificados: escuelas, otras instituciones y areas administrativas publicas',
#  'ahogamientos y sumersiones especificados: granja',
#  'ahogamientos y sumersiones especificados: institucion residencial',
#  'ahogamientos y sumersiones especificados: lugar no especificado',
#  'ahogamientos y sumersiones especificados: otro lugar especificado',
#  'ahogamientos y sumersiones especificados: vivienda',
#  'ahorcamiento, estrangulamiento y sofocacion, de intencion no determinada: area industrial y de la construccion',
#  'ahorcamiento, estrangulamiento y sofocacion, de intencion no determinada: areas de deporte y atletismo',
#  'ahorcamiento, estrangulamiento y sofocacion, de intencion no determinada: calles y carreteras',
#  'ahorcamiento, estrangulamiento y sofocacion, de intencion no determinada: comercio y area de servicios',
#  'ahorcamiento, estrangulamiento y sofocacion, de intencion no determinada: escuelas otras instituciones y areas administrativas',
#  'ahorcamiento, estrangulamiento y sofocacion, de intencion no determinada: granja',
#  'ahorcamiento, estrangulamiento y sofocacion, de intencion no determinada: institucion residencial',
#  'ahorcamiento, estrangulamiento y sofocacion, de intencion no determinada: lugar no especificado',
#  'ahorcamiento, estrangulamiento y sofocacion, de intencion no determinada: otro lugar especificado',
#  'ahorcamiento, estrangulamiento y sofocacion, de intencion no determinada: vivienda',
#  'ahorcamiento, estrangulamiento y sofocación, de intención no determinada',
#  'aids',
#  'aines',
#  'ainhum',
#  'aislamiento',
#  'albinismo',
#  'alcalosis',
#  'alcalosis:',
#  'alcohol, no especificado',
#  'alcoholes',
#  'alcoholismo',
#  'alcoholismo, nivel de intoxicación no especificado',
#  'alcohólica',
#  'alcohólico',
#  'alcohólicos',
#  'aldrich',
#  'alergia',
#  'alergia  ',
#  'alergia a algún medicamento',
#  'alergia a alimentos',
#  'alergia a frutos secos',
#  'alergia a los acaros',
#  'alergia a medicamentos',
#  'alergia al ',
#  'alergia al limón',
#  'alergia al polvo',
#  'alergia al sol',
#  'alergia alimentaria',
#  'alergia cutánea',
#  'alergia de un cosmético',
#  'alergia no especificada',
#  'alergia respiratoria',
#  'alergia solar',
#  'alergiafrutossecos',
#  'alergiaocupacional',
#  'alergias',
#  'alergias alimentarias',
#  'alergias psicológicas',
#  'alergias respiratorias',
#  'alerxia ao trigo',
#  'alesqueriasis',
#  'alexithymia',
#  'alérgica',
#  'alérgica a la penicilina',
#  'alérgica a todo tipo de plantas',
#  'alérgica a varios medicamentos como antibióticos, analgésicos',
#  'alérgico',
#  'alérgico a los perros',
#  'alérgico a un componente de la vacuna',
#  'alérgicos',
#  'alérgicos a ácaros',
#  'alfa talasemia',
#  'algias faciales',
#  'algoneurodistrofia',
#  'algunas complicaciones precoces de traumatismos, no clasificadas en otra parte',
#  'allergy',
#  'alopecia',
#  'alopecia (capitis) total',
#  'alopecia androgenética',
#  'alopecia andrógena',
#  'alopecia andrógena, inducida por drogas',
#  'alopecia andrógena, no especificada',
#  'alopecia apolillada',
#  'alopecia areata',
#  'alopecia areata, no especificada',
#  'alopecia cicatricial [pérdida cicatricial del pelo]',
#  'alopecia cicatricial, no especificada',
#  'alopecia congénita',
#  'alopecia difusa',
#  'alopecia mucinosa',
#  'alopecia parcheada',
#  'alopecia universal',
#  'alopecias andrógenas',
#  'alopecias areatas',
#  'alopecias cicatriciales',
#  'alt hematológicas',
#  'alteraciones  en la  piel',
#  'alteraciones cerebrales del recién nacido',
#  'alteraciones cerebrales especificadas del recién nacido',
#  'alteraciones cognitivas',
#  'alteraciones conductuales graves',
#  'alteraciones de la regulación de la temperatura en el recién nacido',
#  'alteraciones de la secreción salival',
#  'alteraciones de la sensibilidad cutánea',
#  'alteraciones de la sensibilidad cutánea y las no especificadas',
#  'alteraciones de la visión',
#  'alteraciones de la visión en enfermedades clasificadas en otra parte',
#  'alteraciones de la visión y ceguera',
#  'alteraciones de la voz',
#  'alteraciones de la voz y las no especificadas',
#  'alteraciones del ciclo menstrual',
#  'alteraciones del equilibrio del potasio en el recién nacido',
#  'alteraciones del equilibrio del sodio en el recién nacido',
#  'alteraciones del gusto y del olfato y las no especificadas',
#  'alteraciones del habla y las no especificadas',
#  'alteraciones del habla, no clasificadas en otra parte',
#  'alteraciones del sueño',
#  'alteraciones dermatológicas',
#  'alteraciones electrolíticas transitorias del recién nacido',
#  'alteraciones en el funcionamiento de órganos',
#  'alteraciones en la erupción dentaria',
#  'alteraciones en la formación dentaria',
#  'alteraciones especificadas de la regulación de la temperatura del recién nacido',
#  'alteraciones funcionales consecutivas a cirugía cardíaca',
#  'alteraciones hereditarias de la estructura dentaria, no clasificadas en otra parte',
#  'alteraciones metabólicas',
#  'alteraciones metabólicas transitorias del recién nacido',
#  'alteraciones metabólicas y electrolíticas neonatales transitorias',
#  'alteraciones morfológicas congénitas del pelo, no clasificadas en otra parte',
#  'alteraciones visuales',
#  'alteraciones visuales subjetivas',
#  'alteración cerebral no especificada del recién nacido',
#  'alteración de su sistema circulatorio',
#  'alteración del metabolismo y la densidad ósea',
#  'alteración neurpsi',
#  'alteración no especificada de la regulación de la temperatura en el recién nacido',
#  'alteración visual, no especificada',
#  'alucinaciones',
#  'alucinaciones auditivas',
#  'alucinaciones visuales',
#  'alucinaciones visuales complejas de personas y animales.',
#  'alucinaciones, no especificadas',
#  'alucinosis orgánica',
#  'aluminosis (del pulmón)',
#  'alveolitis',
#  'alveolitis del maxilar',
#  'alzeimer',
#  'alzheimer',
#  'alzheimer ',
#  'alzheimer infantil',
#  'alzheimers',
#  'alzhéimer',
#  'amaurosis fugaz',
#  'ambliopía',
#  'ambliopía ex anopsia',
#  'ame tipo 2',
#  'amebiasis',
#  'amebiasis cutánea',
#  'amebiasis intestinal crónica',
#  'amebiasis, no especificada',
#  'ameboma intestinal',
#  'amenaza de aborto',
#  'amenorrea primaria',
#  'amenorrea secundaria',
#  'amenorrea, sin otra especificación',
#  'amielia',
#  'amigdalitis',
#  'amigdalitis aguda',
#  'amigdalitis aguda debida a otros microorganismos especificados',
#  'amigdalitis aguda, no especificada',
#  'amigdalitis calcificadas',
#  'amigdalitis crónica',
#  'amigdalitis estreptocócica',
#  'amiloidosis',
#  'amiloidosis cutánea primaria',
#  'amiloidosis de la piel',
#  'amiloidosis hereditaria por transtirretina',
#  'amiloidosis heredofamiliar neuropática',
#  'amiloidosis heredofamiliar no especificada',
#  'amiloidosis heredofamiliar no neuropática',
#  'amiloidosis limitada a un órgano',
#  'amiloidosis macular',
#  'amiloidosis sistémica',
#  'amiloidosis sistémica secundaria',
#  'amiloidosis ttr hereditaria',
#  'amiloidosis, no especificada',
#  'aminoglucósidos',
#  'amiotrofia neurálgica',
#  'amnesia anterógrada',
#  'amnesia disociativa',
#  'amnesia global transitoria',
#  'amnesia retrógrada',
#  'amnesias',
#  'amplitud de las suturas craneales del recién nacido',
#  'ampolla en el pie',
#  'ampolla subepidérmica',
#  'amputaciones',
#  'amputaciones traumáticas múltiples, no especificadas',
#  'amputaciones traumáticas que afectan múltiples regiones del cuerpo',
#  'amputación de miembro(s)',
#  'amputación del pie, nivel no especificado',
#  'amputación traumatica de dedo',
#  'amputación traumática a nivel de la rodilla',
#  'amputación traumática a nivel del codo',
#  'amputación traumática a nivel del cuello',
#  'amputación traumática a nivel entre el hombro y el codo',
#  'amputación traumática combinada (de parte) de dedo(s) con otras partes de la muñeca y de la mano',
#  'amputación traumática de ambas manos',
#  'amputación traumática de ambas piernas [cualquier nivel]',
#  'amputación traumática de ambos brazos [cualquier nivel]',
#  'amputación traumática de ambos pies',
#  'amputación traumática de cadera y muslo, nivel no especificado',
#  'amputación traumática de dos o más dedos del pie',
#  'amputación traumática de dos o más dedos solamente (completa) (parcial)',
#  'amputación traumática de la articulación de la cadera',
#  'amputación traumática de la cadera y del muslo',
#  'amputación traumática de la mano a nivel de la muñeca',
#  'amputación traumática de la muñeca y de la mano',
#  'amputación traumática de la muñeca y de la mano, nivel no especificado',
#  'amputación traumática de la oreja',
#  'amputación traumática de la pierna',
#  'amputación traumática de la pierna, nivel no especificado',
#  'amputación traumática de miembro inferior, nivel no especificado',
#  'amputación traumática de miembro superior, nivel no especificado',
#  'amputación traumática de miembros superior(es) e inferior(es), cualquier combinación [cualquier nivel]',
#  'amputación traumática de otras partes de la cabeza',
#  'amputación traumática de otras partes de la muñeca y de la mano',
#  'amputación traumática de otras partes del pie',
#  'amputación traumática de otras partes y de las no especificadas del abdomen, región lumbosacra y pelvis',
#  'amputación traumática de otro dedo único (completa) (parcial)',
#  'amputación traumática de órganos genitales externos',
#  'amputación traumática de parte de la cabeza',
#  'amputación traumática de parte del tórax',
#  'amputación traumática de parte no especificada de la cabeza',
#  'amputación traumática de un dedo del pie',
#  'amputación traumática de un pie y la otra pierna [cualquier nivel, excepto pie]',
#  'amputación traumática de una mano y el otro brazo [cualquier nivel, excepto mano]',
#  'amputación traumática del antebrazo',
#  'amputación traumática del antebrazo, nivel no especificado',
#  'amputación traumática del hombro y del brazo',
#  'amputación traumática del hombro y del brazo, nivel no especificado',
#  'amputación traumática del pie a nivel del tobillo',
#  'amputación traumática del pie y del tobillo',
#  'amputación traumática del pulgar (completa) (parcial)',
#  'amputación traumática del tronco, nivel no especificado',
#  'amputación traumática en algún nivel entre la cadera y la rodilla',
#  'amputación traumática en algún nivel entre la rodilla y el tobillo',
#  'amputación traumática en la articulación del hombro',
#  'amputación traumática nivel entre el codo y la muñeca',
#  'amputación traumática que afecta otras combinaciones de regiones del cuerpo',
#  'amyloidosis',
#  'anafilaxia',
#  'anafilaxia con griseofulvina',
#  'analépticos y antagonistas del opio',
#  'analgésicos no narcóticos y antipiréticos, no clasificados en otra parte',
#  'analgésicos no narcóticos, antipiréticos y antirreumáticos, no especificados',
#  'anasalaschacon',
#  'andrógenos y sus congéneres anabólicos',
#  'anemia',
#  'anemia aguda',
#  'anemia aplasica',
#  'anemia aplásica',
#  'anemia aplásica severa',
#  'anemia aplástica constitucional',
#  'anemia aplástica debida a otros agentes externos',
#  'anemia aplástica idiopática',
#  'anemia aplástica inducida por drogas',
#  'anemia aplástica, sin otra especificación',
#  'anemia congénita debida a pérdida de sangre fetal',
#  'anemia de la prematuridad',
#  'anemia de tipo no especificado',
#  'anemia debida a deficiencia de glucosa-6-fosfato deshidrogenasa [g6fd]',
#  'anemia debida a otros trastornos del metabolismo del glutatión',
#  'anemia debida a trastornos de las enzimas glucolíticas',
#  'anemia debida a trastornos del metabolismo de los nucleótidos',
#  'anemia debida a trastornos enzimáticos',
#  ...]

# %%
with open('Output/enfermedades.txt', 'w') as file:
    for item in diseases:
        file.write(f'{item}\n')

# %%
diseases[:30]
# Out:
# ['abcesos intrabdominales',
#  'abdomen agudo',
#  'abertura artificial, no especificada',
#  'aberturas artificiales',
#  'abortadora habitual',
#  'aborto',
#  'aborto espontaneo: completo o no especificado, complicado con infeccion genital y pelviana',
#  'aborto espontaneo: completo o no especificado, complicado por embolia',
#  'aborto espontaneo: completo o no especificado, complicado por hemorragia excesiva o tardia',
#  'aborto espontaneo: completo o no especificado, con otras complicaciones especificadas y las no especificadas',
#  'aborto espontaneo: completo o no especificado, sin complicacion',
#  'aborto espontaneo: incompleto, complicado con infección genital y pelviana',
#  'aborto espontaneo: incompleto, complicado por embolia',
#  'aborto espontaneo: incompleto, complicado por hemorragia excesiva o tardia',
#  'aborto espontaneo: incompleto, con otras complicaciones especificadas y las no especificadas',
#  'aborto espontaneo: incompleto, sin complicacion',
#  'aborto espontáneo',
#  'aborto medico: completo o no especificado, complicado con infeccion genital y pelviana',
#  'aborto medico: completo o no especificado, complicado por embolia',
#  'aborto medico: completo o no especificado, complicado por hemorragia excesiva o tardia',
#  'aborto medico: completo o no especificado, con otras complicaciones especificadas y las no especificadas',
#  'aborto medico: completo o no especificado, sin complicacion',
#  'aborto medico: incompleto, complicado con infección genital y pelviana',
#  'aborto medico: incompleto, complicado por embolia',
#  'aborto medico: incompleto, complicado por hemorragia excesiva o tardia',
#  'aborto medico: incompleto, con otras complicaciones especificadas y las no especificadas',
#  'aborto medico: incompleto, sin complicacion',
#  'aborto médico',
#  'aborto no especificado',
#  'aborto no especificado: completo o no especificado, complicado con infeccion genital y pelviana']

# %%
diseases[11000:11030]
# Out:
# ['malformaciones congénitas del pelo',
#  'malformaciones congénitas del pene',
#  'malformaciones congénitas del pulmón',
#  'malformaciones congénitas del riñón',
#  'malformaciones congénitas del riñón, especificadas',
#  'malformaciones congénitas del segmento anterior del ojo',
#  'malformaciones congénitas del segmento posterior del ojo',
#  'malformaciones congénitas del sistema circulatorio',
#  'malformaciones congénitas del sistema circulatorio, especificadas',
#  'malformaciones congénitas del sistema digestivo',
#  'malformaciones congénitas del sistema digestivo, especificadas',
#  'malformaciones congénitas del sistema nervioso',
#  'malformaciones congénitas del sistema nervioso, especificadas',
#  'malformaciones congénitas del sistema osteomuscular',
#  'malformaciones congénitas del sistema osteomuscular, no clasificadas en otra parte',
#  'malformaciones congénitas del sistema respiratorio',
#  'malformaciones congénitas del sistema urinario',
#  'malformaciones congénitas del sistema vascular periférico',
#  'malformaciones congénitas del sistema vascular periférico, especificadas',
#  'malformaciones congénitas del tórax óseo',
#  'malformaciones congénitas del uréter',
#  'malformaciones congénitas del útero y del cuello uterino',
#  'malformaciones congénitas especificadas de cara y cuello',
#  'malformaciones congénitas especificadas de la médula espinal',
#  'malformaciones congénitas especificadas de los huesos del cráneo y de la cara',
#  'malformaciones congénitas especificadas del (de los) miembro(s)',
#  'malformaciones congénitas especificadas del sistema respiratorio',
#  'malformaciones congénitas múltiples, no clasificadas en otra parte',
#  'malformaciones congénitas, deformidades y anomalías cromosómicas',
#  'malformaciones congénitas, especificadas']

# %%
# Plot number of words in disease names

plt.hist([len(disease.split()) for disease in diseases], bins=20)
plt.title('Words per disease name')
plt.xlabel('words per disease name')
plt.show()

# %%
# The longest disease name
max(diseases, key=len)
# Out:
# 'envenenamiento autoinfligido intencionalmente por, y exposicion a drogas antiepilepticas, sedantes, hipnoticas, antiparkinsonianas y psicotropicas, no clasificadas en otra parte: escuelas, otras instituciones y areas administrativas publicas'

# %% [markdown]
# ### NER tags annotation

# %%
# Create pattern dictionary for model training

patterns = [{'label': 'DISEASE', 'pattern': item} for item in diseases]

# %%
patterns[:5]
# Out:
# [{'label': 'DISEASE', 'pattern': 'abcesos intrabdominales'},
#  {'label': 'DISEASE', 'pattern': 'abdomen agudo'},
#  {'label': 'DISEASE', 'pattern': 'abertura artificial, no especificada'},
#  {'label': 'DISEASE', 'pattern': 'aberturas artificiales'},
#  {'label': 'DISEASE', 'pattern': 'abortadora habitual'}]

# %%
import spacy
nlp = spacy.load("es_core_news_sm") # load NLP model for Spanish

# %%
# Create new blank model using EntityRuler

from spacy.lang.es import Spanish
custom_nlp = Spanish()
ruler = custom_nlp.add_pipe("entity_ruler")
ruler.add_patterns(patterns)
ruler.to_disk('disease-ruler')

# %%
# Load saved custom NER model and add it as new pipe to standard model
ruler = spacy.load('disease-ruler', vocab=nlp.vocab)
nlp.add_pipe("entity_ruler", source=ruler, before="ner")

# %%
# Examples of input and desired output for testing

input_examples = [
    [
        'Estoy enferma y dejaron de pagarme mi sueldo bien ahi sindicato de comercio #carlosperez #endometriosis #fibromialgia #artritis #soycomercio\n\n\n',
        ['Estoy', 'enferma', 'y', 'dejaron', 'de', 'pagarme', 'mi', 'sueldo', 'bien', 'ahi', 'sindicato', 'de', 'comercio', '#', 'carlosperez', '#', 'endometriosis', '#', 'fibromialgia', '#', 'artritis', '#', 'soycomercio', '\n\n\n'],
        ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'B', 'O', 'B', 'O', 'O', 'O']
    ],
   
    
    [
        '¿Qué probabilidad hay de no pillar la gripe si me paso la vida en el hospital?\n\n\n\n\n\n',
        ['¿', 'Qué', 'probabilidad', 'hay', 'de', 'no', 'pillar', 'la', 'gripe', 'si', 'me', 'paso', 'la', 'vida', 'en', 'el', 'hospital', '?', '\n\n\n\n\n\n'],
        ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
    ],

    
    [
         'Empezamos a emparejar el marcador covid-19 https://t.co/dGEUtRuxAo\n\n\n\n\n\n',
         ['Empezamos', 'a', 'emparejar', 'el', 'marcador', 'covid-19', 'https://t.co/dGEUtRuxAo', '\n\n\n\n\n\n'],
         ['O', 'O', 'O', 'O', 'O', 'B', 'O', 'O']
    ],
         
       
    [
        'y me dio un ataque de ansiedad\n\n\n\n\n\n',
        ['y', 'me', 'dio', 'un', 'ataque', 'de', 'ansiedad', '\n\n\n\n\n\n'],
        ['O', 'O', 'O', 'O', 'B', 'I', 'I', 'O']
    ]
]

# %%
# Function to get Tokens and corresponding IOB annotations for Diseases ( (ignoring all other entities except DISEASES)

def tokens_IOB_tag(text):
    doc = nlp(text, disable='ner')       # use CUSTOM 'entity_ruler' model instead of original 'ner'
    tokens = [ent.text for ent in doc] 
    ner_tags = [ent.ent_iob_ for ent in doc]
    return tokens, ner_tags

# %%
# Function to recognise all entities (both standard and custom)

def NER(text):
    doc = nlp(text)
    for entity in doc.ents:
        print(entity.text, entity.label_)

# %%
text = 'Estoy enferma y dejaron de pagarme mi sueldo bien ahi sindicato de comercio #carlosperez #endometriosis #fibromialgia #artritis #soycomercio\n\n\n'

# %%
for example in input_examples:
    NER(example[0])
    print('===')
# Out:
# comercio #carlosperez # LOC
# endometriosis DISEASE
# fibromialgia DISEASE
# artritis DISEASE
# soycomercio
#
#
#  LOC
# ===
# gripe DISEASE
# hospital? LOC
# ===
# covid-19 DISEASE
# https://t.co/dGEUtRuxAo
#
#
#
#
#
#  PER
# ===
# ataque de ansiedad DISEASE
# ===

# %%
for example in input_examples:
    tokens, ner_tags = tokens_IOB_tag(example[0])
    print(tokens, '\n', ner_tags, '\n\n')
# Out:
# ['Estoy', 'enferma', 'y', 'dejaron', 'de', 'pagarme', 'mi', 'sueldo', 'bien', 'ahi', 'sindicato', 'de', 'comercio', '#', 'carlosperez', '#', 'endometriosis', '#', 'fibromialgia', '#', 'artritis', '#', 'soycomercio', '\n\n\n']
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'B', 'O', 'B', 'O', 'O', 'O']
#
#
# ['¿', 'Qué', 'probabilidad', 'hay', 'de', 'no', 'pillar', 'la', 'gripe', 'si', 'me', 'paso', 'la', 'vida', 'en', 'el', 'hospital', '?', '\n\n\n\n\n\n']
#  ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O']
#
#
# ['Empezamos', 'a', 'emparejar', 'el', 'marcador', 'covid-19', 'https://t.co/dGEUtRuxAo', '\n\n\n\n\n\n']
#  ['O', 'O', 'O', 'O', 'O', 'B', 'O', 'O']
#
#
# ['y', 'me', 'dio', 'un', 'ataque', 'de', 'ansiedad', '\n\n\n\n\n\n']
#  ['O', 'O', 'O', 'O', 'B', 'I', 'I', 'O']

# %%
# Test for tokens_IOB_tag()

for i, example in enumerate(input_examples):
    print(f'* Example {i+1} *')
    tokens, ner_tags = tokens_IOB_tag(example[0])
    if tokens == example[1]:
        print('Tokens CORRECT')
    else:
        print('Tokens WRONG')
        print(f'Calculated: {tokens}\nOriginal:   {example[1]}\n')
        
    if ner_tags == example[2]:
        print('NER tags CORRECT\n\n')
    else:
        print('NER tags WRONG')
        print(f'Calculated: {ner_tags}\nOriginal:   {example[2]}\n\n')
# Out:
# * Example 1 *
# Tokens CORRECT
# NER tags CORRECT
#
#
# * Example 2 *
# Tokens CORRECT
# NER tags CORRECT
#
#
# * Example 3 *
# Tokens CORRECT
# NER tags CORRECT
#
#
# * Example 4 *
# Tokens CORRECT
# NER tags CORRECT

# %% [markdown]
# ## Create annotated dataset from tweet files

# %%
filelist = [file for file in Path(training_dir).iterdir() if file.glob('*.txt')]
len(filelist)
# Out:
# 5000

# %%
# Preparation of output dataset with two columns:
# tokens: array of tokens of the tweet; 
# ner_tags: array of tag annotations (I, O, B).

tokens_tags_list = []
tweet_len = []
for file in filelist:
    tweet = file.read_text(encoding="UTF-8")
    tokens_tags_list.append(tokens_IOB_tag(tweet))
    tweet_len.append(len(tweet))

# %%
max(tweet_len)
# Out:
# 331

# %%
# Plot Lenght of tweets

plt.hist(tweet_len, bins=25)
plt.title('Tweet lenght')
plt.xlabel('characters per tweet')
plt.show()

# %%
annotated_df = pd.DataFrame(tokens_tags_list, columns = ['tokens', 'ner_tags'])
annotated_df
# Out:
#                                                  tokens  \
# 0     [Estoy, enferma, y, dejaron, de, pagarme, mi, ...
# 1     [Ok, chicas, .., hoy, vamos, a, hablar, de, ve...
# 2     [AUTOESTIMA, Y, ANSIEDAD, !, \n \n, La, ansied...
# 3     [El, #, tabaquismo, está, detrás, de, un, alto...
# 4     [Hoy, ,, Día, mundial, contra, el, cáncer, ,, ...
# ...                                                 ...
# 4995  [El, acoso, escolar, puede, producir, depresió...
# 4996  [Hemos, pasado, por, el, CEPA, de, Los, Rosale...
# 4997  [Ojalá, la, familia, de, los, que, golpearon, ...
# 4998  [Mientras, los, refrescos, sean, la, bebida, m...
# 4999  [🟢TRATAMIENTO, :, Se, recomienda, calcio, intr...
#
#                                                ner_tags
# 0     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1     [O, O, O, O, O, O, O, O, B, O, B, O, O, O, B, ...
# 2     [O, O, O, O, O, O, B, O, O, O, O, O, O, B, I, ...
# 3     [O, O, B, O, O, O, O, O, O, O, O, O, O, O, B, ...
# 4     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# ...                                                 ...
# 4995  [O, O, O, O, O, O, O, B, O, B, O, B, O, B, I, ...
# 4996  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4997  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4998  [O, O, O, O, O, O, O, O, O, O, O, O, B, O, B, ...
# 4999  [O, O, O, O, O, O, O, O, O, B, O, O, B, O, O, ...
#
# [5000 rows x 2 columns]

# %%
print(annotated_df.iloc[15][0])
# Out:
# ['Estudio', 'transversal', ',', 'publicado', 'en', '“', 'European', 'Journal', 'of', 'Clinical', 'Nutrition', '(', 'enero', '2019', ')', ',', 'que', 'revela', 'una', 'asociación', 'inversa', 'entre', 'ciertos', 'modelos', 'dietéticos', '(', '“', 'saludable', '”', ',', '“', 'pescado', 'y', 'pollo', '”', ')', 'y', 'trastornos', 'psicológicos', '(', 'depresión', ',', 'ansiedad', 'y', 'estrés', ')', '.', '\n', 'https://t.co/wPiV9requv', '\n\n\n']

# %%
# Saving of token list and Ner_tags to CSV file
annotated_df.to_csv('Output/annotated.tsv', index=None,  encoding='UTF-8', sep='\t')
